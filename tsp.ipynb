# %% [markdown]
# Copyright **`(c)`** 2024 Giovanni Squillero `<giovanni.squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free under certain conditions — see the [`license`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %%
import logging
from itertools import combinations
import pandas as pd
import numpy as np
from geopy.distance import geodesic
import networkx as nx

from icecream import ic

logging.basicConfig(level=logging.DEBUG)

# %%
CITIES = pd.read_csv('cities/russia.csv', header=None, names=['name', 'lat', 'lon'])
DIST_MATRIX = np.zeros((len(CITIES), len(CITIES)))
for c1, c2 in combinations(CITIES.itertuples(), 2):
    DIST_MATRIX[c1.Index, c2.Index] = DIST_MATRIX[c2.Index, c1.Index] = geodesic(
        (c1.lat, c1.lon), (c2.lat, c2.lon)
    ).km
CITIES.head()
# Out:
#           name    lat     lon
# 0       Abakan  53.72   91.43
# 1      Achinsk  56.28   90.50
# 2   Almetyevsk  54.90   52.31
# 3      Angarsk  52.57  103.91
# 4  Arkhangelsk  64.57   40.53

# %% [markdown]
# ## Lab2 - TSP
#
# https://www.wolframcloud.com/obj/giovanni.squillero/Published/Lab2-tsp.nb

# %%
dist_matrix = np.zeros((len(CITIES), len(CITIES)))
for c1, c2 in combinations(CITIES.itertuples(), 2):
    dist_matrix[c1.Index, c2.Index] = dist_matrix[c2.Index, c1.Index] = geodesic(
        (c1.lat, c1.lon), (c2.lat, c2.lon)
    ).km

# i do dist_matrix[c1.Index, c2.Index] = dist_matrix[c2.Index, c1.Index] because combinations return only distinct pairs

# %%
def tsp_cost(tsp):
    assert tsp[0] == tsp[-1]
    assert set(tsp) == set(range(len(CITIES)))

    tot_cost = 0
    for c1, c2 in zip(tsp, tsp[1:]):
        tot_cost += DIST_MATRIX[c1, c2]
    return tot_cost

# %% [markdown]
# ## First Greedy Algorithm

# %% [markdown]
# Greedy means that we always choose the best option at each step, don't look far away in the future.
# *I am in a city and I go to the nearest city.*

# %%
visited = np.full(len(CITIES), False)
dist = DIST_MATRIX.copy()
city = 0
visited[city] = True
tsp = list()
tsp.append(int(city))
while not np.all(visited):
    dist[:, city] = np.inf
    closest = np.argmin(dist[city])
    logging.debug(
        f"step: {CITIES.at[city,'name']} -> {CITIES.at[closest,'name']} ({DIST_MATRIX[city,closest]:.2f}km)"
    )
    visited[closest] = True
    city = closest
    tsp.append(int(city))

logging.debug(
    f"step: {CITIES.at[tsp[-1],'name']} -> {CITIES.at[tsp[0],'name']} ({DIST_MATRIX[tsp[-1],tsp[0]]:.2f}km)"
)
tsp.append(tsp[0])


logging.info(f"result: Found a path of {len(tsp)-1} steps, total length {tsp_cost(tsp):.2f}km")
# Out:
# DEBUG:root:step: Abakan -> Krasnoyarsk (276.58km)
# DEBUG:root:step: Krasnoyarsk -> Achinsk (161.71km)
# DEBUG:root:step: Achinsk -> Kemerovo (296.59km)
# DEBUG:root:step: Kemerovo -> Leninsk‐Kuznetskiy (74.76km)
# DEBUG:root:step: Leninsk‐Kuznetskiy -> Prokopyevsk (91.87km)
# DEBUG:root:step: Prokopyevsk -> Novokuznetsk (30.63km)
# DEBUG:root:step: Novokuznetsk -> Biysk (187.38km)
# DEBUG:root:step: Biysk -> Barnaul (132.82km)
# DEBUG:root:step: Barnaul -> Novosibirsk (194.50km)
# DEBUG:root:step: Novosibirsk -> Tomsk (206.90km)
# DEBUG:root:step: Tomsk -> Seversk (14.97km)
# DEBUG:root:step: Seversk -> Rubtsovsk (613.13km)
# DEBUG:root:step: Rubtsovsk -> Omsk (647.47km)
# DEBUG:root:step: Omsk -> Tobolsk (475.40km)
# DEBUG:root:step: Tobolsk -> Tyumen (200.98km)
# DEBUG:root:step: Tyumen -> Kurgan (189.69km)
# DEBUG:root:step: Kurgan -> Kopeysk (236.87km)
# DEBUG:root:step: Kopeysk -> Chelyabinsk (14.72km)
# DEBUG:root:step: Chelyabinsk -> Miass (87.20km)
# DEBUG:root:step: Miass -> Zlatoust (33.88km)
# DEBUG:root:step: Zlatoust -> Pervouralsk (194.64km)
# DEBUG:root:step: Pervouralsk -> Yekaterinburg (40.19km)
# DEBUG:root:step: Yekaterinburg -> Kamensk‐Uralskiy (95.20km)
# DEBUG:root:step: Kamensk‐Uralskiy -> Nizhniy Tagil (205.75km)
# DEBUG:root:step: Nizhniy Tagil -> Perm (220.37km)
# DEBUG:root:step: Perm -> Berezniki (159.92km)
# DEBUG:root:step: Berezniki -> Izhevsk (353.17km)
# DEBUG:root:step: Izhevsk -> Neftekamsk (107.05km)
# DEBUG:root:step: Neftekamsk -> Naberezhnye Chelny (129.52km)
# DEBUG:root:step: Naberezhnye Chelny -> Nizhnekamsk (31.95km)
# DEBUG:root:step: Nizhnekamsk -> Almetyevsk (88.07km)
# DEBUG:root:step: Almetyevsk -> Oktyabrskiy (88.27km)
# DEBUG:root:step: Oktyabrskiy -> Ufa (170.17km)
# DEBUG:root:step: Ufa -> Sterlitamak (128.14km)
# DEBUG:root:step: Sterlitamak -> Salavat (29.01km)
# DEBUG:root:step: Salavat -> Orenberg (185.10km)
# DEBUG:root:step: Orenberg -> Orenburg (0.37km)
# DEBUG:root:step: Orenburg -> Novotroitsk (232.42km)
# DEBUG:root:step: Novotroitsk -> Orsk (21.66km)
# DEBUG:root:step: Orsk -> Magnitogorsk (247.00km)
# DEBUG:root:step: Magnitogorsk -> Samara (588.03km)
# DEBUG:root:step: Samara -> Novokuybyshevsk (17.80km)
# DEBUG:root:step: Novokuybyshevsk -> Tolyatti (49.80km)
# DEBUG:root:step: Tolyatti -> Syzran (77.41km)
# DEBUG:root:step: Syzran -> Ulyanovsk (129.19km)
# DEBUG:root:step: Ulyanovsk -> Dimitrovgrad (75.41km)
# DEBUG:root:step: Dimitrovgrad -> Kazan (169.13km)
# DEBUG:root:step: Kazan -> Novocheboksarsk (109.88km)
# DEBUG:root:step: Novocheboksarsk -> Cheboksary (15.59km)
# DEBUG:root:step: Cheboksary -> Yoshkar‐Ola (68.49km)
# DEBUG:root:step: Yoshkar‐Ola -> Nizhny Novgorod (240.88km)
# DEBUG:root:step: Nizhny Novgorod -> Dzerzhinsk (34.91km)
# DEBUG:root:step: Dzerzhinsk -> Arzamas (98.38km)
# DEBUG:root:step: Arzamas -> Murom (114.53km)
# DEBUG:root:step: Murom -> Kovrov (98.78km)
# DEBUG:root:step: Kovrov -> Vladimir (62.07km)
# DEBUG:root:step: Vladimir -> Orekhovo‐Zuevo (95.53km)
# DEBUG:root:step: Orekhovo‐Zuevo -> Noginsk (34.00km)
# DEBUG:root:step: Noginsk -> Elektrostal (6.68km)
# DEBUG:root:step: Elektrostal -> Zheleznodorozhnyy (26.94km)
# DEBUG:root:step: Zheleznodorozhnyy -> Balashikha (6.96km)
# DEBUG:root:step: Balashikha -> Shchyolkovo (11.97km)
# DEBUG:root:step: Shchyolkovo -> Korolyov (12.70km)
# DEBUG:root:step: Korolyov -> Mytishchi (5.74km)
# DEBUG:root:step: Mytishchi -> Khimki (18.28km)
# DEBUG:root:step: Khimki -> Zelenograd (10.91km)
# DEBUG:root:step: Zelenograd -> Moscow (29.58km)
# DEBUG:root:step: Moscow -> Lyubertsy (19.17km)
# DEBUG:root:step: Lyubertsy -> Zhukovskiy (26.33km)
# DEBUG:root:step: Zhukovskiy -> Podolsk (47.16km)
# DEBUG:root:step: Podolsk -> Odintsovo (32.00km)
# DEBUG:root:step: Odintsovo -> Obninsk (76.71km)
# DEBUG:root:step: Obninsk -> Serpukhov (54.96km)
# DEBUG:root:step: Serpukhov -> Tula (81.18km)
# DEBUG:root:step: Tula -> Novomoskovsk (41.70km)
# DEBUG:root:step: Novomoskovsk -> Ryazan (115.09km)
# DEBUG:root:step: Ryazan -> Kolomna (80.15km)
# DEBUG:root:step: Kolomna -> Sergiyev Posad (143.98km)
# DEBUG:root:step: Sergiyev Posad -> Tver (150.18km)
# DEBUG:root:step: Tver -> Rybinsk (220.67km)
# DEBUG:root:step: Rybinsk -> Yaroslavl (78.17km)
# DEBUG:root:step: Yaroslavl -> Kostroma (65.38km)
# DEBUG:root:step: Kostroma -> Ivanovo (84.72km)
# DEBUG:root:step: Ivanovo -> Vologda (254.39km)
# DEBUG:root:step: Vologda -> Cherepovets (114.80km)
# DEBUG:root:step: Cherepovets -> Petrozavodsk (358.19km)
# DEBUG:root:step: Petrozavodsk -> Saint Petersburg (302.88km)
# DEBUG:root:step: Saint Petersburg -> Kolpino (25.47km)
# DEBUG:root:step: Kolpino -> Velikiy Novgorod (142.44km)
# DEBUG:root:step: Velikiy Novgorod -> Pskov (189.82km)
# DEBUG:root:step: Pskov -> Velikie Luki (212.88km)
# DEBUG:root:step: Velikie Luki -> Smolensk (198.09km)
# DEBUG:root:step: Smolensk -> Bryansk (230.10km)
# DEBUG:root:step: Bryansk -> Oryol (115.74km)
# DEBUG:root:step: Oryol -> Kursk (138.18km)
# DEBUG:root:step: Kursk -> Staryy Oskol (124.13km)
# DEBUG:root:step: Staryy Oskol -> Voronezh (109.10km)
# DEBUG:root:step: Voronezh -> Lipetsk (103.13km)
# DEBUG:root:step: Lipetsk -> Yelets (75.22km)
# DEBUG:root:step: Yelets -> Tambov (198.07km)
# DEBUG:root:step: Tambov -> Penza (245.48km)
# DEBUG:root:step: Penza -> Saransk (109.72km)
# DEBUG:root:step: Saransk -> Balakovo (295.88km)
# DEBUG:root:step: Balakovo -> Engels (128.88km)
# DEBUG:root:step: Engels -> Saratov (9.98km)
# DEBUG:root:step: Saratov -> Kamyshin (169.44km)
# DEBUG:root:step: Kamyshin -> Volzhskiy (152.69km)
# DEBUG:root:step: Volzhskiy -> Volgograd (23.11km)
# DEBUG:root:step: Volgograd -> Volgodonsk (218.86km)
# DEBUG:root:step: Volgodonsk -> Shakhty (147.54km)
# DEBUG:root:step: Shakhty -> Novoshakhtinsk (20.74km)
# DEBUG:root:step: Novoshakhtinsk -> Novocherkassk (38.39km)
# DEBUG:root:step: Novocherkassk -> Rostov‐na‐Donu (35.01km)
# DEBUG:root:step: Rostov‐na‐Donu -> Bataysk (11.52km)
# DEBUG:root:step: Bataysk -> Taganrog (64.29km)
# DEBUG:root:step: Taganrog -> Krasnodar (243.49km)
# DEBUG:root:step: Krasnodar -> Maykop (100.83km)
# DEBUG:root:step: Maykop -> Armavir (90.38km)
# DEBUG:root:step: Armavir -> Stavropol (67.23km)
# DEBUG:root:step: Stavropol -> Nevinnomyssk (45.59km)
# DEBUG:root:step: Nevinnomyssk -> Cherkessk (38.78km)
# DEBUG:root:step: Cherkessk -> Kislovodsk (67.64km)
# DEBUG:root:step: Kislovodsk -> Pyatigorsk (31.40km)
# DEBUG:root:step: Pyatigorsk -> Nalchik (75.94km)
# DEBUG:root:step: Nalchik -> Vladikavkaz (100.08km)
# DEBUG:root:step: Vladikavkaz -> Nazran (21.26km)
# DEBUG:root:step: Nazran -> Groznyy (73.92km)
# DEBUG:root:step: Groznyy -> Khasavyurt (72.55km)
# DEBUG:root:step: Khasavyurt -> Makhachkala (79.91km)
# DEBUG:root:step: Makhachkala -> Kaspiysk (15.94km)
# DEBUG:root:step: Kaspiysk -> Derbent (105.61km)
# DEBUG:root:step: Derbent -> Astrakhan (477.07km)
# DEBUG:root:step: Astrakhan -> Elista (295.65km)
# DEBUG:root:step: Elista -> Sochi (464.97km)
# DEBUG:root:step: Sochi -> Novorossiysk (200.16km)
# DEBUG:root:step: Novorossiysk -> Belgorod (660.82km)
# DEBUG:root:step: Belgorod -> Kaluga (437.86km)
# DEBUG:root:step: Kaluga -> Kirov (936.75km)
# DEBUG:root:step: Kirov -> Syktyvkar (347.95km)
# DEBUG:root:step: Syktyvkar -> Arkhangelsk (610.18km)
# DEBUG:root:step: Arkhangelsk -> Severodvinsk (33.55km)
# DEBUG:root:step: Severodvinsk -> Murmansk (572.02km)
# DEBUG:root:step: Murmansk -> Kaliningrad (1712.77km)
# DEBUG:root:step: Kaliningrad -> Nefteyugansk (3086.69km)
# DEBUG:root:step: Nefteyugansk -> Surgut (43.14km)
# DEBUG:root:step: Surgut -> Nizhnevartovsk (173.64km)
# DEBUG:root:step: Nizhnevartovsk -> Noyabrsk (254.53km)
# DEBUG:root:step: Noyabrsk -> Novyy Urengoy (328.30km)
# DEBUG:root:step: Novyy Urengoy -> Norilsk (612.52km)
# DEBUG:root:step: Norilsk -> Bratsk (1599.47km)
# DEBUG:root:step: Bratsk -> Angarsk (439.00km)
# DEBUG:root:step: Angarsk -> Irkutsk (34.88km)
# DEBUG:root:step: Irkutsk -> Ulan‐Ude (238.28km)
# DEBUG:root:step: Ulan‐Ude -> Chita (402.25km)
# DEBUG:root:step: Chita -> Blagoveshchensk (1002.31km)
# DEBUG:root:step: Blagoveshchensk -> Khabarovsk (588.32km)
# DEBUG:root:step: Khabarovsk -> Komsomolsk‐na‐Amure (274.21km)
# DEBUG:root:step: Komsomolsk‐na‐Amure -> Yuzhno‐Sakhalinsk (582.17km)
# DEBUG:root:step: Yuzhno‐Sakhalinsk -> Nakhodka (901.85km)
# DEBUG:root:step: Nakhodka -> Artyom (82.51km)
# DEBUG:root:step: Artyom -> Vladivostok (34.21km)
# DEBUG:root:step: Vladivostok -> Ussuriysk (74.97km)
# DEBUG:root:step: Ussuriysk -> Yakutsk (2034.16km)
# DEBUG:root:step: Yakutsk -> Magadan (1173.79km)
# DEBUG:root:step: Magadan -> Petropavlovsk‐Kamchatskiy (875.16km)
# DEBUG:root:step: Petropavlovsk‐Kamchatskiy -> Kyzyl (4230.63km)
# DEBUG:root:step: Kyzyl -> Abakan (299.57km)
# INFO:root:result: Found a path of 167 steps, total length 42334.16km

# %% [markdown]
# ## Second Greedy Algorithm

# %% [markdown]
# in this case, we look for a "segment". This algorithm lead to build a tree without cycles using segments.

# %%
def cyclic(edges):
    G = nx.Graph()
    G.add_edges_from(edges)
    try:
        nx.find_cycle(G)
        return True
    except:
        return False

# %% [markdown]
# `segments` : each element of the list is a tuple of two cities and the distance between them. So `segments` contains all the possible segments between the cities.

# %%
segments = [
    ({c1, c2}, float(DIST_MATRIX[c1, c2])) for c1, c2 in combinations(range(len(CITIES)), 2)
]
visited = set()
edges = set()

# %% [markdown]
# Order the segments by distance and then we start from the shortest one. If the two cities of the segment are not already in the tree, we add the segment to the tree.

# %%
shortest = next(_ for _ in sorted(segments, key=lambda e: e[1]))
visited |= shortest[0]
visited
edges |= {tuple(shortest[0])}
segments = [s for s in segments if not cyclic(edges | {tuple(s[0])})]

# %%
segments
# Out:
# [({0, 1}, 291.12871812096597),
#  ({0, 2}, 2516.33442321499),
#  ({0, 3}, 843.679166213213),
#  ({0, 4}, 3050.3327570180104),
#  ({0, 5}, 3697.257751542974),
#  ({0, 6}, 3169.5429738640505),
#  ({0, 7}, 3025.825566168284),
#  ({0, 8}, 3160.2480682832283),
#  ({0, 9}, 2898.5097152436815),
#  ({0, 10}, 3364.293337838562),
#  ({0, 11}, 510.48040419758183),
#  ({0, 12}, 3659.116686030305),
#  ({0, 13}, 3674.232708952557),
#  ({0, 14}, 2194.6122160833356),
#  ({0, 15}, 439.31947457577616),
#  ({0, 16}, 2481.4335921593824),
#  ({0, 17}, 716.7680282426004),
#  ({0, 18}, 3680.756755100788),
#  ({0, 19}, 2796.2681940600255),
#  ({0, 20}, 1938.0889218280688),
#  ({0, 21}, 3264.6854322830545),
#  ({0, 22}, 3678.9247499298162),
#  ({0, 23}, 1488.4462769418906),
#  ({0, 24}, 3412.8183943767885),
#  ({0, 25}, 2707.300979312825),
#  ({0, 26}, 3021.42923733918),
#  ({0, 27}, 3335.5365148607657),
#  ({0, 28}, 3414.741242958905),
#  ({0, 29}, 3026.843158723314),
#  ({0, 30}, 3501.175002654965),
#  ({0, 31}, 872.0827902020271),
#  ({0, 32}, 3145.496905689025),
#  ({0, 33}, 2419.5553577201435),
#  ({0, 34}, 4426.222011078868),
#  ({0, 35}, 3513.2202141544108),
#  ({0, 36}, 1893.286455679377),
#  ({0, 37}, 3136.646191087911),
#  ({0, 38}, 3401.135925373215),
#  ({0, 39}, 2691.4566578235404),
#  ({0, 40}, 389.8718024429532),
#  ({0, 41}, 3067.64536044094),
#  ({0, 42}, 3446.306435790382),
#  ({0, 43}, 3391.2845761869735),
#  ({0, 44}, 2606.496290219797),
#  ({0, 45}, 3659.422247752528),
#  ({0, 46}, 3341.0174775673077),
#  ({0, 47}, 3646.624687524286),
#  ({0, 48}, 3085.3943802378276),
#  ({0, 49}, 1924.7822432234261),
#  ({0, 50}, 3367.708941377522),
#  ({0, 51}, 3127.920943851446),
#  ({0, 52}, 3145.448482456393),
#  ({0, 53}, 3835.1451315295244),
#  ({0, 54}, 276.57891829161815),
#  ({0, 55}, 1688.2745725632449),
#  ({0, 56}, 3643.789330132984),
#  ({0, 57}, 299.5706068697576),
#  ({0, 58}, 359.46710668995365),
#  ({0, 59}, 3389.2287974820556),
#  ({0, 60}, 3372.55359963718),
#  ({0, 61}, 3573.474426480244),
#  ({0, 62}, 2131.931115085928),
#  ({0, 63}, 3403.822637886788),
#  ({0, 64}, 3787.138823516397),
#  ({0, 65}, 2025.1963553713892),
#  ({0, 66}, 3385.6882688738274),
#  ({0, 67}, 3374.290208548805),
#  ({0, 68}, 3127.453092734736),
#  ({0, 69}, 3373.39636008132),
#  ({0, 70}, 2496.9351802671326),
#  ({0, 71}, 3250.934314682358),
#  ({0, 72}, 3626.2356282305286),
#  ({0, 73}, 3567.05666805501),
#  ({0, 74}, 2369.0950438079944),
#  ({0, 75}, 1384.6418986268002),
#  ({0, 76}, 3664.9357075014364),
#  ({0, 77}, 2528.877634525728),
#  ({0, 78}, 1197.548572316675),
#  ({0, 79}, 2006.8426870839628),
#  ({0, 80}, 2986.5337205240303),
#  ({0, 81}, 3333.414479227303),
#  ({0, 82}, 1748.3753598078374),
#  ({0, 83}, 2781.3836745489184),
#  ({0, 84}, 3621.083166152472),
#  ({0, 85}, 2720.717409547018),
#  ({0, 86}, 285.7186653682532),
#  ({0, 87}, 3413.5096910830935),
#  ({0, 88}, 3933.641788992364),
#  ({0, 89}, 3612.2713937055332),
#  ({0, 90}, 571.1111759233225),
#  ({0, 91}, 2246.7427522457465),
#  ({0, 92}, 1602.0074206896347),
#  ({0, 93}, 1392.5180904699312),
#  ({0, 94}, 3470.3889841904847),
#  ({0, 95}, 3408.207284362842),
#  ({0, 96}, 2455.3724886169794),
#  ({0, 97}, 1177.3900592788918),
#  ({0, 98}, 3302.352679061173),
#  ({0, 99}, 2435.5567735899203),
#  ({0, 100}, 2435.68053681658),
#  ({0, 101}, 2226.4013438123625),
#  ({0, 102}, 3592.5387015894685),
#  ({0, 103}, 3028.9878981970287),
#  ({0, 104}, 2226.727517708623),
#  ({0, 105}, 2011.3256961013115),
#  ({0, 106}, 4303.358115596992),
#  ({0, 107}, 3393.590213681545),
#  ({0, 108}, 3402.6171524707697),
#  ({0, 109}, 311.51214124451),
#  ({0, 110}, 3840.3079555196805),
#  ({0, 111}, 3628.1412218638025),
#  ({0, 112}, 3655.9988059371344),
#  ({0, 113}, 733.5719618706679),
#  ({0, 114}, 3300.236571219201),
#  ({0, 115}, 3241.0287572828315),
#  ({0, 116}, 3655.8271064494743),
#  ({0, 117}, 2329.5888854282816),
#  ({0, 118}, 2703.613961928076),
#  ({0, 119}, 2982.082599002631),
#  ({0, 120}, 3029.6051986031166),
#  ({0, 121}, 3335.4367404966897),
#  ({0, 122}, 3429.4873625832697),
#  ({0, 123}, 3083.874133341819),
#  ({0, 124}, 529.1850932553855),
#  ({0, 125}, 3596.992988479329),
#  ({0, 126}, 3356.5695639476753),
#  ({0, 127}, 3755.3615357590006),
#  ({0, 128}, 3876.1817415680644),
#  ({0, 129}, 3561.401975313897),
#  ({0, 130}, 3638.331533755379),
#  ({0, 131}, 2320.1642850556163),
#  ({0, 132}, 1359.8691119744183),
#  ({0, 133}, 2529.257145191859),
#  ({0, 134}, 2811.2593194850397),
#  ({0, 135}, 3709.084472853699),
#  ({0, 136}, 3271.5552480923475),
#  ({0, 137}, 1521.0396292394546),
#  ({0, 138}, 2734.6561658234746),
#  ({0, 139}, 515.1574084940215),
#  ({0, 140}, 3446.1282341502433),
#  ({0, 141}, 3447.6958145630233),
#  ({0, 142}, 1672.3437857188921),
#  ({0, 143}, 2285.232492241214),
#  ({0, 144}, 1110.0829040201286),
#  ({0, 145}, 2776.7290490929568),
#  ({0, 146}, 3130.033191736948),
#  ({0, 147}, 3776.753139357555),
#  ({0, 148}, 3650.9982128806673),
#  ({0, 149}, 3586.021484105557),
#  ({0, 150}, 3207.0878991805685),
#  ({0, 151}, 3166.1099238444044),
#  ({0, 152}, 3481.959405332877),
#  ({0, 153}, 3265.5626334965536),
#  ({0, 154}, 3150.8629638506663),
#  ({0, 155}, 3242.546593499637),
#  ({0, 156}, 3452.307088639677),
#  ({0, 157}, 2409.701565025497),
#  ({0, 158}, 3193.2996719429157),
#  ({0, 159}, 1972.1129068009698),
#  ({0, 160}, 3459.139534763563),
#  ({0, 161}, 2746.5661021774263),
#  ({0, 162}, 3645.9540580160024),
#  ({0, 163}, 3398.3516955505297),
#  ({0, 164}, 3362.128416786423),
#  ({0, 165}, 3355.471137817192),
#  ({0, 166}, 2050.0639245241405),
#  ({1, 2}, 2381.8200272570098),
#  ({1, 3}, 961.2575902584988),
#  ({1, 4}, 2816.838328875078),
#  ({1, 5}, 3620.8987298709812),
#  ({1, 6}, 3260.367862003036),
#  ({1, 7}, 2870.5700761674666),
#  ({1, 8}, 3100.0297558680722),
#  ({1, 9}, 2784.0491587287993),
#  ({1, 10}, 3195.267447990969),
#  ({1, 11}, 541.747384685155),
#  ({1, 12}, 3562.017729264827),
#  ({1, 13}, 3541.9426914309106),
#  ({1, 14}, 2010.6049998904198),
#  ({1, 15}, 541.9292080780918),
#  ({1, 16}, 2525.2572740348405),
#  ({1, 17}, 693.4132857403422),
#  ({1, 18}, 3524.037585166056),
#  ({1, 19}, 2639.6665968471584),
#  ({1, 20}, 1817.7624424093783),
#  ({1, 21}, 3069.6831795532526),
#  ({1, 22}, 3611.2863528019952),
#  ({1, 23}, 1563.318388189196),
#  ({1, 24}, 3388.8159046318065),
#  ({1, 25}, 2574.337414919116),
#  ({1, 26}, 2857.7693511138777),
#  ({1, 27}, 3167.421272202845),
#  ({1, 28}, 3339.7956092519084),
#  ({1, 29}, 2912.9272970098614),
#  ({1, 30}, 3455.870507159258),
#  ({1, 31}, 994.2832707551821),
#  ({1, 32}, 2971.3944008884473),
#  ({1, 33}, 2263.766195796674),
#  ({1, 34}, 4233.591024442294),
#  ({1, 35}, 3350.8464670579215),
#  ({1, 36}, 1753.955265348743),
#  ({1, 37}, 3033.5122750881856),
#  ({1, 38}, 3367.790545008402),
#  ({1, 39}, 2541.8162486577307),
#  ({1, 40}, 296.5933724505771),
#  ({1, 41}, 3102.7750683650524),
#  ({1, 42}, 3405.3664994129817),
#  ({1, 43}, 3220.6953761645677),
#  ({1, 44}, 2427.707661705112),
#  ({1, 45}, 3597.1839015330556),
#  ({1, 46}, 3179.173575485663),
#  ({1, 47}, 3439.353103568248),
#  ({1, 48}, 3093.714316011733),
#  ({1, 49}, 1805.4976543599248),
#  ({1, 50}, 3197.522883772489),
#  ({1, 51}, 2947.353931429377),
#  ({1, 52}, 2977.3552364532075),
#  ({1, 53}, 3750.617377123945),
#  ({1, 54}, 161.70854599830338),
#  ({1, 55}, 1569.7945421722395),
#  ({1, 56}, 3502.2325293446397),
#  ({1, 57}, 568.5453696637113),
#  ({1, 58}, 328.3385508210685),
#  ({1, 59}, 3248.9776042206954),
#  ({1, 60}, 3204.445814527839),
#  ({1, 61}, 3467.5260078464307),
#  ({1, 62}, 2031.6598420922753),
#  ({1, 63}, 3369.061247197049),
#  ({1, 64}, 3709.728206199491),
#  ({1, 65}, 1904.5892103859758),
#  ({1, 66}, 3216.4922949013994),
#  ({1, 67}, 3114.922498206042),
#  ({1, 68}, 2967.361799775222),
#  ({1, 69}, 3203.137835828267),
#  ({1, 70}, 2353.3185175530048),
#  ({1, 71}, 3342.639839924284),
#  ({1, 72}, 3570.6828987070935),
#  ({1, 73}, 3518.6243255949867),
#  ({1, 74}, 2223.9724739756066),
#  ({1, 75}, 1157.6174953772604),
#  ({1, 76}, 3594.376581735147),
#  ({1, 77}, 2384.988246638159),
#  ({1, 78}, 958.3375214200115),
#  ({1, 79}, 1843.4265101471683),
#  ({1, 80}, 2822.907417892896),
#  ({1, 81}, 3164.822177804669),
#  ({1, 82}, 1460.0008265540278),
#  ({1, 83}, 2625.2788950196837),
#  ({1, 84}, 3523.015204534701),
#  ({1, 85}, 2600.7678819917483),
#  ({1, 86}, 355.76365511857347),
#  ({1, 87}, 3258.458028988141),
#  ({1, 88}, 3846.8960744644673),
#  ({1, 89}, 3511.2144699672144),
#  ({1, 90}, 495.75635185836774),
#  ({1, 91}, 2174.7219167874186),
#  ({1, 92}, 1320.612396084832),
#  ({1, 93}, 1130.869204785267),
#  ({1, 94}, 3304.4138962000115),
#  ({1, 95}, 3239.066958833778),
#  ({1, 96}, 2328.245906385298),
#  ({1, 97}, 1083.331475671747),
#  ({1, 98}, 3134.9126603880272),
#  ({1, 99}, 2345.2454066547557),
#  ({1, 100}, 2345.409667306558),
#  ({1, 101}, 2155.5271070346657),
#  ({1, 102}, 3441.534125692231),
#  ({1, 103}, 2896.281021206886),
#  ({1, 104}, 2059.968161208019),
#  ({1, 105}, 1862.370677124414),
#  ({1, 106}, 4232.016308982156),
#  ({1, 107}, 3176.1207249147637),
#  ({1, 108}, 3235.8518606625466),
#  ({1, 109}, 358.72990658388187),
#  ({1, 110}, 3642.349891745611),
#  ({1, 111}, 3566.2402208457165),
#  ({1, 112}, 3558.0207389449547),
#  ({1, 113}, 806.9512916589503),
#  ({1, 114}, 3143.936167339618),
#  ({1, 115}, 3055.519045924911),
#  ({1, 116}, 3447.1025064168934),
#  ({1, 117}, 2221.8559068879676),
#  ({1, 118}, 2583.247354362701),
#  ({1, 119}, 2840.589028489173),
#  ({1, 120}, 2914.781745183866),
#  ({1, 121}, 3162.614998743676),
#  ({1, 122}, 3266.369160247411),
#  ({1, 123}, 2850.2641079704026),
#  ({1, 124}, 351.51429340517365),
#  ({1, 125}, 3497.1208231055707),
#  ({1, 126}, 3186.875502315151),
#  ({1, 127}, 3583.279671756237),
#  ({1, 128}, 3804.377092175611),
#  ({1, 129}, 3427.1743569790638),
#  ({1, 130}, 3564.816504169917),
#  ({1, 131}, 2209.1763730431244),
#  ({1, 132}, 1128.029192520581),
#  ({1, 133}, 2320.2740028358544),
#  ({1, 134}, 2687.096863049227),
#  ({1, 135}, 3608.610787913618),
#  ({1, 136}, 3134.6456224713306),
#  ({1, 137}, 1352.7718950150281),
#  ({1, 138}, 2609.7633629392585),
#  ({1, 139}, 342.3333975258669),
#  ({1, 140}, 3288.9863957410157),
#  ({1, 141}, 3267.26475932014),
#  ({1, 142}, 1523.5384452619708),
#  ({1, 143}, 2159.6021984201916),
#  ({1, 144}, 1221.4740195207457),
#  ({1, 145}, 2640.4984698796684),
#  ({1, 146}, 3218.1375140205005),
#  ({1, 147}, 3591.611774953748),
#  ({1, 148}, 3452.542021400985),
#  ({1, 149}, 3538.338061031695),
#  ({1, 150}, 3039.3795049132436),
#  ({1, 151}, 3259.996461274903),
#  ({1, 152}, 3390.125564097731),
#  ({1, 153}, 3171.7021177297156),
#  ({1, 154}, 2957.245087063767),
#  ({1, 155}, 3148.962125629669),
#  ({1, 156}, 3318.3958465109667),
#  ({1, 157}, 2294.4089607927062),
#  ({1, 158}, 3012.590521961779),
#  ({1, 159}, 1824.6690875464174),
#  ({1, 160}, 3316.4616566049776),
#  ({1, 161}, 2585.7824468628282),
#  ({1, 162}, 3666.201243491956),
#  ({1, 163}, 3227.1241593439704),
#  ({1, 164}, 3193.609126289999),
#  ({1, 165}, 3188.9329106831865),
#  ({1, 166}, 1926.108289832052),
#  ({2, 3}, 3337.2807615110537),
#  ({2, 4}, 1260.232902559196),
#  ({2, 5}, 1360.309034567467),
#  ({2, 6}, 5638.256355969908),
#  ({2, 7}, 543.7040004916693),
#  ({2, 8}, 997.2605014743947),
#  ({2, 9}, 438.61946048007724),
#  ({2, 10}, 914.7589781899627),
#  ({2, 11}, 2044.9871612182421),
#  ({2, 12}, 1230.2194657952139),
#  ({2, 13}, 1160.4551064466598),
#  ({2, 14}, 569.8853624694483),
#  ({2, 15}, 2165.1322244028606),
#  ({2, 16}, 4874.764108263351),
#  ({2, 17}, 3050.5770055405806),
#  ({2, 18}, 1181.6881420198677),
#  ({2, 19}, 347.64102764172725),
#  ({2, 20}, 583.5106293194699),
#  ({2, 21}, 991.212852054856),
#  ({2, 22}, 1390.2208207325566),
#  ({2, 23}, 3942.033990139238),
#  ({2, 24}, 1457.7783720819323),
#  ({2, 25}, 192.57722996589612),
#  ({2, 26}, 577.4246121154727),
#  ({2, 27}, 884.0163535024483),
#  ({2, 28}, 1111.760737862754),
#  ({2, 29}, 560.2328966576299),
#  ({2, 30}, 1374.8365000681224),
#  ({2, 31}, 3369.0532867712036),
#  ({2, 32}, 744.0743141528272),
#  ({2, 33}, 224.61385384237656),
#  ({2, 34}, 2027.9393128037307),
#  ({2, 35}, 1032.1141930257252),
#  ({2, 36}, 627.8647619409178),
#  ({2, 37}, 710.3118811663728),
#  ({2, 38}, 1379.0945066374709),
#  ({2, 39}, 222.90586037681643),
#  ({2, 40}, 2134.231807956645),
#  ({2, 41}, 5434.1555265195575),
#  ({2, 42}, 1360.1997421566732),
#  ({2, 43}, 946.7787366327035),
#  ({2, 44}, 442.67815802910394),
#  ({2, 45}, 1403.6220055027409),
#  ({2, 46}, 864.933736537551),
#  ({2, 47}, 1406.8508179448684),
#  ({2, 48}, 5384.361226981644),
#  ({2, 49}, 597.6415052314094),
#  ({2, 50}, 923.0585272325048),
#  ({2, 51}, 771.7718560547241),
#  ({2, 52}, 710.2220013078892),
#  ({2, 53}, 1451.0602338906626),
#  ({2, 54}, 2543.2948192452873),
#  ({2, 55}, 830.6058402988507),
#  ({2, 56}, 1127.7964289798572),
#  ({2, 57}, 2783.81908289258),
#  ({2, 58}, 2156.8680566202065),
#  ({2, 59}, 873.1468548296813),
#  ({2, 60}, 918.5651826461475),
#  ({2, 61}, 5413.073231358829),
#  ({2, 62}, 464.97560547386814),
#  ({2, 63}, 1370.8086020611481),
#  ({2, 64}, 1438.8238973739933),
#  ({2, 65}, 498.3603824294824),
#  ({2, 66}, 935.4662214208673),
#  ({2, 67}, 1846.1964096785387),
#  ({2, 68}, 657.0030651926689),
#  ({2, 69}, 928.6666105815747),
#  ({2, 70}, 87.95216179789581),
#  ({2, 71}, 5720.693736574012),
#  ({2, 72}, 1414.693608155445),
#  ({2, 73}, 1409.2385826510429),
#  ({2, 74}, 180.56505654151604),
#  ({2, 75}, 1380.2505372724538),
#  ({2, 76}, 1361.3291249384984),
#  ({2, 77}, 88.07358557290732),
#  ({2, 78}, 1574.8593908950743),
#  ({2, 79}, 579.6882583989558),
#  ({2, 80}, 546.8995303357879),
#  ({2, 81}, 884.1206281959877),
#  ({2, 82}, 2407.853125067014),
#  ({2, 83}, 332.7738824549183),
#  ({2, 84}, 1189.8492599809356),
#  ({2, 85}, 253.04460306980377),
#  ({2, 86}, 2243.804795248348),
#  ({2, 87}, 915.836328620254),
#  ({2, 88}, 1535.855258571933),
#  ({2, 89}, 1170.0492338416423),
#  ({2, 90}, 1945.2641893655082),
#  ({2, 91}, 574.9591211016684),
#  ({2, 92}, 1801.58724264222),
#  ({2, 93}, 1610.242218730924),
#  ({2, 94}, 1002.8383218857464),
#  ({2, 95}, 956.3149263183413),
#  ({2, 96}, 88.27174813599686),
#  ({2, 97}, 1346.2290309079065),
#  ({2, 98}, 850.2204815304965),
#  ({2, 99}, 393.43008715887515),
#  ({2, 100}, 393.7603440853672),
#  ({2, 101}, 589.6644660418978),
#  ({2, 102}, 1084.7651820658448),
#  ({2, 103}, 514.51134590153),
#  ({2, 104}, 421.96528234035105),
#  ({2, 105}, 527.2709280476539),
#  ({2, 106}, 6269.980231770611),
#  ({2, 107}, 1297.4287875486882),
#  ({2, 108}, 941.4278328515242),
#  ({2, 109}, 2214.3412198102565),
#  ({2, 110}, 1508.953855175032),
#  ({2, 111}, 1377.7283621841004),
#  ({2, 112}, 1223.8233569494275),
#  ({2, 113}, 1951.3453989439),
#  ({2, 114}, 808.7119370054334),
#  ({2, 115}, 899.7401317907564),
#  ({2, 116}, 1426.717776531556),
#  ({2, 117}, 290.9396136848989),
#  ({2, 118}, 236.23647324051487),
#  ({2, 119}, 468.17578822006465),
#  ({2, 120}, 559.2409522424018),
#  ({2, 121}, 905.796785804761),
#  ({2, 122}, 953.8422399660595),
#  ({2, 123}, 1280.7656177388767),
#  ({2, 124}, 2031.3379978906928),
#  ({2, 125}, 1159.7218413709309),
#  ({2, 126}, 910.511862951634),
#  ({2, 127}, 1297.8313057386913),
#  ({2, 128}, 1549.9994365456123),
#  ({2, 129}, 1046.310597367789),
#  ({2, 130}, 1320.9841516362399),
#  ({2, 131}, 276.0590026961315),
#  ({2, 132}, 1423.1871718688642),
#  ({2, 133}, 759.1206009971249),
#  ({2, 134}, 316.75462049023224),
#  ({2, 135}, 1265.9716510803146),
#  ({2, 136}, 755.296218120436),
#  ({2, 137}, 1045.0511985884275),
#  ({2, 138}, 241.60530531293065),
#  ({2, 139}, 2041.6782255771047),
#  ({2, 140}, 952.6295205276145),
#  ({2, 141}, 1047.8445006533993),
#  ({2, 142}, 859.9375386361878),
#  ({2, 143}, 239.99048964035777),
#  ({2, 144}, 3600.9732372250896),
#  ({2, 145}, 260.4154843192531),
#  ({2, 146}, 5595.019894783543),
#  ({2, 147}, 1375.6775461524219),
#  ({2, 148}, 1343.108268290625),
#  ({2, 149}, 1430.3309872155896),
#  ({2, 150}, 763.8312591828292),
#  ({2, 151}, 5638.9754406658685),
#  ({2, 152}, 1084.1421241658618),
#  ({2, 153}, 874.1179044618779),
#  ({2, 154}, 891.4304168160489),
#  ({2, 155}, 854.6465936335196),
#  ({2, 156}, 937.3075790740435),
#  ({2, 157}, 4309.12815617587),
#  ({2, 158}, 826.8057636239229),
#  ({2, 159}, 562.0332633772277),
#  ({2, 160}, 943.8987812262227),
#  ({2, 161}, 339.28492270898545),
#  ({2, 162}, 5966.351812936393),
#  ({2, 163}, 956.2164764895066),
#  ({2, 164}, 910.5555658110385),
#  ({2, 165}, 896.0905389604753),
#  ({2, 166}, 470.05123236703),
#  ({3, 4}, 3734.8797719503436),
#  ({3, 5}, 4540.483966110956),
#  ({3, 6}, 2325.9767667630545),
#  ({3, 7}, 3831.371264764169),
#  ({3, 8}, 4003.8650931102507),
#  ({3, 9}, 3730.9002521232906),
#  ({3, 10}, 4156.233769475158),
#  ({3, 11}, 1352.904522759314),
#  ({3, 12}, 4498.524589398132),
#  ({3, 13}, 4497.69335210311),
#  ({3, 14}, 2970.10703296414),
#  ({3, 15}, 1267.6189023172988),
#  ({3, 16}, 1655.1749020025993),
#  ({3, 17}, 438.996171695688),
#  ({3, 18}, 4485.129400783943),
#  ({3, 19}, 3600.5213125387613),
#  ({3, 20}, 2766.0180705863527),
#  ({3, 21}, 4023.191584681572),
#  ({3, 22}, 4522.593718736544),
#  ({3, 23}, 653.4158777239907),
#  ({3, 24}, 4249.475034246922),
#  ({3, 25}, 3529.4773010234294),
#  ({3, 26}, 3819.026941063327),
#  ({3, 27}, 4128.471033760076),
#  ({3, 28}, 4258.010685439109),
#  ({3, 29}, 3859.6217719171245),
#  ({3, 30}, 4343.139263292803),
#  ({3, 31}, 34.87952402791192),
#  ({3, 32}, 3931.832613595228),
#  ({3, 33}, 3224.3355911508647),
#  ({3, 34}, 5186.5437822823),
#  ({3, 35}, 4312.103565342745),
#  ({3, 36}, 2709.9828284955674),
#  ({3, 37}, 3973.768837971053),
#  ({3, 38}, 4240.61988865197),
#  ({3, 39}, 3501.6052542858106),
#  ({3, 40}, 1206.5294433468118),
#  ({3, 41}, 2243.4853045204113),
#  ({3, 42}, 4287.505660111088),
#  ({3, 43}, 4181.49285964779),
#  ({3, 44}, 3387.750854585919),
#  ({3, 45}, 4503.039327888098),
#  ({3, 46}, 4140.4273087840165),
#  ({3, 47}, 4383.98689534819),
#  ({3, 48}, 2285.037610152717),
#  ({3, 49}, 2753.1940353565205),
#  ({3, 50}, 4158.373292949832),
#  ({3, 51}, 3906.502394350685),
#  ({3, 52}, 3938.451559984991),
#  ({3, 53}, 4677.403321946134),
#  ({3, 54}, 802.8340787281992),
#  ({3, 55}, 2516.3709905949063),
#  ({3, 56}, 4460.834835427101),
#  ({3, 57}, 658.9373276296318),
#  ({3, 58}, 1194.081460055311),
#  ({3, 59}, 4207.081587855215),
#  ({3, 60}, 4165.487259097679),
#  ({3, 61}, 2954.170776288613),
#  ({3, 62}, 2968.6441721596493),
#  ({3, 63}, 4243.666702635524),
#  ({3, 64}, 4630.291767204282),
#  ({3, 65}, 2853.1990804465017),
#  ({3, 66}, 4177.4367831845875),
#  ({3, 67}, 3974.7910035064606),
#  ({3, 68}, 3928.5519143659335),
#  ({3, 69}, 4163.978477168342),
#  ({3, 70}, 3311.5727375191577),
#  ({3, 71}, 2407.447357834806),
#  ({3, 72}, 4469.455015267172),
#  ({3, 73}, 4409.469124789473),
#  ({3, 74}, 3182.4651626488876),
#  ({3, 75}, 2100.755035723761),
#  ({3, 76}, 4508.527050097621),
#  ({3, 77}, 3343.3481198603113),
#  ({3, 78}, 1894.1372149190966),
#  ({3, 79}, 2804.4922398195686),
#  ({3, 80}, 3784.1648501180707),
#  ({3, 81}, 4125.834521022315),
#  ({3, 82}, 2038.45839822803),
#  ({3, 83}, 3586.075919410531),
#  ({3, 84}, 4460.190849190969),
#  ({3, 85}, 3550.2750160226133),
#  ({3, 86}, 1129.345803775404),
#  ({3, 87}, 4219.357763827378),
#  ({3, 88}, 4775.565827162836),
#  ({3, 89}, 4450.467607887275),
#  ({3, 90}, 1403.631827331962),
#  ({3, 91}, 3089.725225691861),
#  ({3, 92}, 2135.342240401548),
#  ({3, 93}, 2025.4912727442695),
#  ({3, 94}, 4265.5746614582295),
#  ({3, 95}, 4200.010166144994),
#  ({3, 96}, 3280.7064184877245),
#  ({3, 97}, 2012.687906243975),
#  ({3, 98}, 4096.017557613955),
#  ({3, 99}, 3275.6143908962154),
#  ({3, 100}, 3275.74808311574),
#  ({3, 101}, 3069.481974300113),
#  ({3, 102}, 4402.003951661695),
#  ({3, 103}, 3851.669519787877),
#  ({3, 104}, 3021.2224610269404),
#  ({3, 105}, 2821.2953015371513),
#  ({3, 106}, 3601.3554844633613),
#  ({3, 107}, 4112.285431690347),
#  ({3, 108}, 4196.979561062953),
#  ({3, 109}, 1155.0645273396324),
#  ({3, 110}, 4593.113177965544),
#  ({3, 111}, 4471.750717971317),
#  ({3, 112}, 4495.155629962324),
#  ({3, 113}, 1555.7506033420543),
#  ({3, 114}, 4104.920168859164),
#  ({3, 115}, 4013.0850154535005),
#  ({3, 116}, 4390.523404178756),
#  ({3, 117}, 3163.9822647892343),
#  ({3, 118}, 3532.9387367842105),
#  ({3, 119}, 3798.737902174377),
#  ({3, 120}, 3861.979821500743),
#  ({3, 121}, 4123.146480710935),
#  ({3, 122}, 4227.622627842694),
#  ({3, 123}, 3767.8990625523934),
#  ({3, 124}, 1307.6200402048942),
#  ({3, 125}, 4435.54761258881),
#  ({3, 126}, 4147.78053438443),
#  ({3, 127}, 4543.737776191158),
#  ({3, 128}, 4719.748152633821),
#  ({3, 129}, 4383.530994504378),
#  ({3, 130}, 4481.763738850381),
#  ({3, 131}, 3153.222054640427),
#  ({3, 132}, 2067.4134555897563),
#  ({3, 133}, 3267.478117317209),
#  ({3, 134}, 3638.7300454926913),
#  ({3, 135}, 4547.530285933239),
#  ({3, 136}, 4091.676225474966),
#  ({3, 137}, 2313.8370969937155),
#  ({3, 138}, 3561.632188744114),
#  ({3, 139}, 1296.671621122471),
#  ({3, 140}, 4250.066162028995),
#  ({3, 141}, 4226.156035804304),
#  ({3, 142}, 2481.7845365218004),
#  ({3, 143}, 3111.121022034044),
#  ({3, 144}, 266.65176098156167),
#  ({3, 145}, 3596.863301705494),
#  ({3, 146}, 2286.3614479330868),
#  ({3, 147}, 4548.6935584518405),
#  ({3, 148}, 4403.358243939099),
#  ({3, 149}, 4428.310261464487),
#  ({3, 150}, 4000.4872152517537),
#  ({3, 151}, 2322.7928156867383),
#  ({3, 152}, 4322.599723907952),
#  ({3, 153}, 4105.558533463117),
#  ({3, 154}, 3911.657884768108),
#  ({3, 155}, 4082.59497080719),
#  ({3, 156}, 4274.56673799448),
#  ({3, 157}, 1859.5956788830165),
#  ({3, 158}, 3971.6402251016584),
#  ({3, 159}, 2783.1757430953166),
#  ({3, 160}, 4275.243329311782),
#  ({3, 161}, 3546.9389010429336),
#  ({3, 162}, 2830.1269515997997),
#  ({3, 163}, 4187.842854035092),
#  ({3, 164}, 4154.620046051648),
#  ({3, 165}, 4150.081919771646),
#  ({3, 166}, 2876.3863443271007),
#  ({4, 5}, 2179.8734016944454),
#  ({4, 6}, 5835.855291706176),
#  ({4, 7}, 1039.865080808652),
#  ({4, 8}, 2080.005814856712),
#  ({4, 9}, 1457.7205566135099),
#  ({4, 10}, 987.3281349928952),
#  ({4, 11}, 2710.634220329536),
#  ({4, 12}, 1941.1663198417475),
#  ({4, 13}, 1571.7077310491293),
#  ({4, 14}, 1022.6560301316194),
#  ({4, 15}, 2843.443603532862),
#  ({4, 16}, 5003.76684510697),
#  ({4, 17}, 3345.385663942085),
#  ({4, 18}, 1306.6415449594258),
#  ({4, 19}, 1009.5778958463014),
#  ({4, 20}, 1559.1922710350866),
#  ({4, 21}, 621.728557190079),
#  ({4, 22}, 2259.377546652119),
#  ({4, 23}, 4222.272093420356),
#  ({4, 24}, 2553.511121884774),
#  ({4, 25}, 1255.742667545159),
#  ({4, 26}, 941.8039669569342),
#  ({4, 27}, 984.9330666960578),
#  ({4, 28}, 2044.2149645626873),
#  ({4, 29}, 1491.2666170107493),
#  ({4, 30}, 2388.5977355452196),
#  ({4, 31}, 3769.6764140522464),
#  ({4, 32}, 842.7379502700653),
#  ({4, 33}, 1100.7237552458719),
#  ({4, 34}, 1562.9173387405401),
#  ({4, 35}, 1142.4084116823688),
#  ({4, 36}, 1474.5266934134002),
#  ({4, 37}, 1636.7257854712925),
#  ({4, 38}, 2455.6118964054244),
#  ({4, 39}, 1090.3291346818423),
#  ({4, 40}, 2673.460571254787),
#  ({4, 41}, 5493.904903278865),
#  ({4, 42}, 2403.5141526203497),
#  ({4, 43}, 981.8300428433031),
#  ({4, 44}, 821.5502159833806),
#  ({4, 45}, 2303.6756600984886),
#  ({4, 46}, 1061.7068583806783),
#  ({4, 47}, 744.3599019765356),
#  ({4, 48}, 5375.689004035898),
#  ({4, 49}, 1571.5469684350082),
#  ({4, 50}, 975.1358887857521),
#  ({4, 51}, 758.0342239732723),
#  ({4, 52}, 915.7650298712988),
#  ({4, 53}, 2177.2462361160574),
#  ({4, 54}, 2957.526409556646),
#  ({4, 55}, 1698.1192141841282),
#  ({4, 56}, 1451.9146088073542),
#  ({4, 57}, 3349.344247560204),
#  ({4, 58}, 2726.7377276060624),
#  ({4, 59}, 1332.0824744161316),
#  ({4, 60}, 1002.161947341345),
#  ({4, 61}, 5056.168127342664),
#  ({4, 62}, 1620.5331497335715),
#  ({4, 63}, 2443.0037373398927),
#  ({4, 64}, 2221.9483516187634),
#  ({4, 65}, 1518.9259130254125),
#  ({4, 66}, 995.6035128575483),
#  ({4, 67}, 588.4608051862101),
#  ({4, 68}, 1006.1569847984027),
#  ({4, 69}, 977.0030317626371),
#  ({4, 70}, 1182.5414444419966),
#  ({4, 71}, 5916.6264150925335),
#  ({4, 72}, 2353.1868761181645),
#  ({4, 73}, 2392.582831129001),
#  ({4, 74}, 1207.5662636092886),
#  ({4, 75}, 1665.7165367093983),
#  ({4, 76}, 2221.3339682670153),
#  ({4, 77}, 1172.6937278693767),
#  ({4, 78}, 1858.7660808955316),
#  ({4, 79}, 1271.6578134527178),
#  ({4, 80}, 937.3954007172368),
#  ({4, 81}, 978.2878948240188),
#  ({4, 82}, 2091.3216918507173),
#  ({4, 83}, 1015.6777451202378),
#  ({4, 84}, 1909.6443190795983),
#  ({4, 85}, 1383.6881591634651),
#  ({4, 86}, 2840.5478876031525),
#  ({4, 87}, 1174.6501453553985),
#  ({4, 88}, 2216.238360670145),
#  ({4, 89}, 1873.1069103591133),
#  ({4, 90}, 2543.955252304185),
#  ({4, 91}, 1810.3775555599266),
#  ({4, 92}, 1661.5221329157475),
#  ({4, 93}, 1709.746720704681),
#  ({4, 94}, 1077.1810137739842),
#  ({4, 95}, 1007.4763222959103),
#  ({4, 96}, 1336.6369413928287),
#  ({4, 97}, 2097.0485918811833),
#  ({4, 98}, 978.5862905341882),
#  ({4, 99}, 1653.3275390984027),
#  ({4, 100}, 1653.6636502349393),
#  ({4, 101}, 1820.6112153330437),
#  ({4, 102}, 1316.7189847356024),
#  ({4, 103}, 1291.6941715172761),
#  ({4, 104}, 1111.1077270661374),
#  ({4, 105}, 1350.8918731985787),
#  ({4, 106}, 5930.594831369861),
#  ({4, 107}, 437.07569478393464),
#  ({4, 108}, 1032.6882495262255),
#  ({4, 109}, 2810.413484344585),
#  ({4, 110}, 993.8231749952159),
#  ({4, 111}, 2289.5125093420143),
#  ({4, 112}, 1930.1120984992074),
#  ({4, 113}, 2736.535733215512),
#  ({4, 114}, 1109.3456794812535),
#  ({4, 115}, 732.1665505020912),
#  ({4, 116}, 739.2876543022936),
#  ({4, 117}, 1521.0570446241097),
#  ({4, 118}, 1379.109033632918),
#  ({4, 119}, 1186.4648990265703),
#  ({4, 120}, 1482.481185722108),
#  ({4, 121}, 928.4821863253792),
#  ({4, 122}, 1088.9624923204171),
#  ({4, 123}, 33.55259473217984),
#  ({4, 124}, 2522.2362902629525),
#  ({4, 125}, 1877.3150017923422),
#  ({4, 126}, 975.7343044001607),
#  ({4, 127}, 1188.5371716780642),
#  ({4, 128}, 2334.5622104349395),
#  ({4, 129}, 1486.1708846771453),
#  ({4, 130}, 2175.844594184802),
#  ({4, 131}, 1496.7717069151013),
#  ({4, 132}, 1691.5672624210533),
#  ({4, 133}, 610.1754322019827),
#  ({4, 134}, 1347.4861891792373),
#  ({4, 135}, 1934.1961467614212),
#  ({4, 136}, 1319.8260182169295),
#  ({4, 137}, 1626.1776458040504),
#  ({4, 138}, 1335.6434869590396),
#  ({4, 139}, 2536.620401736761),
#  ({4, 140}, 1166.7688154158918),
#  ({4, 141}, 895.0552164368183),
#  ({4, 142}, 1574.7427003033451),
#  ({4, 143}, 1389.8424194856425),
#  ({4, 144}, 3969.1900652845725),
#  ({4, 145}, 1222.8052245618114),
#  ({4, 146}, 5787.372397175246),
#  ({4, 147}, 1066.643563770459),
#  ({4, 148}, 832.8111093765311),
#  ({4, 149}, 2410.5596341530963),
#  ({4, 150}, 939.2745500215594),
#  ({4, 151}, 5844.986165393997),
#  ({4, 152}, 1901.9817745041853),
#  ({4, 153}, 1781.730121808031),
#  ({4, 154}, 597.1339916992769),
#  ({4, 155}, 1775.2717725117727),
#  ({4, 156}, 1433.0901305893026),
#  ({4, 157}, 4110.679350639842),
#  ({4, 158}, 775.2453580208261),
#  ({4, 159}, 1382.871147444623),
#  ({4, 160}, 1338.2874937741963),
#  ({4, 161}, 969.2738892113339),
#  ({4, 162}, 5942.536632289722),
#  ({4, 163}, 977.7878825568242),
#  ({4, 164}, 992.3341113310471),
#  ({4, 165}, 1012.7634845228555),
#  ({4, 166}, 1486.7789519239568),
#  ({5, 6}, 6866.356740315363),
#  ({5, 7}, 1171.4449185853236),
#  ({5, 8}, 560.546961663184),
#  ({5, 9}, 923.7808861207378),
#  ({5, 10}, 1223.0704330667634),
#  ({5, 11}, 3191.2893052516965),
#  ({5, 12}, 261.4205921958891),
#  ({5, 13}, 710.7456757796186),
#  ({5, 14}, 1917.9678080781355),
#  ({5, 15}, 3289.6970538721994),
#  ({5, 16}, 6145.625015799655),
#  ({5, 17}, 4311.148968471742),
#  ({5, 18}, 1040.573279862902),
#  ({5, 19}, 1311.8513013870272),
#  ({5, 20}, 1830.0144048082375),
#  ({5, 21}, 1588.2743681822574),
#  ({5, 22}, 107.76136398292776),
#  ({5, 23}, 5176.179859170729),
#  ({5, 24}, 664.4403917098043),
#  ({5, 25}, 1194.6603320800218),
#  ({5, 26}, 1262.1719490081373),
#  ({5, 27}, 1216.1317087409873),
#  ({5, 28}, 282.55917766448044),
#  ({5, 29}, 813.111007709854),
#  ({5, 30}, 411.1414540586461),
#  ({5, 31}, 4569.286856805065),
#  ({5, 32}, 1337.2249238183126),
#  ({5, 33}, 1565.200504304915),
#  ({5, 34}, 1823.8785913772547),
#  ({5, 35}, 1117.5085801819887),
#  ({5, 36}, 1929.2143487750757),
#  ({5, 37}, 652.8757397315821),
#  ({5, 38}, 573.3865199900681),
#  ({5, 39}, 1323.5708247574676),
#  ({5, 40}, 3343.7775962442424),
#  ({5, 41}, 6719.524582013037),
#  ({5, 42}, 478.49693956021423),
#  ({5, 43}, 1239.889390380529),
#  ({5, 44}, 1621.788568235069),
#  ({5, 45}, 174.98495820867947),
#  ({5, 46}, 1134.5849729569857),
#  ({5, 47}, 1786.80356227809),
#  ({5, 48}, 6691.33558926665),
#  ({5, 49}, 1840.0501394396706),
#  ({5, 50}, 1237.834778010519),
#  ({5, 51}, 1421.8932913017652),
#  ({5, 52}, 1264.8917681947007),
#  ({5, 53}, 168.75651286732636),
#  ({5, 54}, 3781.022343915136),
#  ({5, 55}, 2066.049960148737),
#  ({5, 56}, 833.2996645157299),
#  ({5, 57}, 3926.4728867409626),
#  ({5, 58}, 3348.354290878852),
#  ({5, 59}, 855.5723619582116),
#  ({5, 60}, 1209.7014487406122),
#  ({5, 61}, 6773.0016328092715),
#  ({5, 62}, 1596.1442383270414),
#  ({5, 63}, 558.238748939729),
#  ({5, 64}, 90.38243401908682),
#  ({5, 65}, 1747.8822790435931),
#  ({5, 66}, 1222.1153856706687),
#  ({5, 67}, 2708.2102233843584),
#  ({5, 68}, 1178.6523892105615),
#  ({5, 69}, 1237.9533422305267),
#  ({5, 70}, 1428.6976496219843),
#  ({5, 71}, 6947.905586142706),
#  ({5, 72}, 259.3748827192107),
#  ({5, 73}, 354.82827920544116),
#  ({5, 74}, 1540.7754139709796),
#  ({5, 75}, 2726.866265117059),
#  ({5, 76}, 76.88610019207681),
#  ({5, 77}, 1405.0725482059913),
#  ({5, 78}, 2911.5242242538493),
#  ({5, 79}, 1932.5649651754047),
#  ({5, 80}, 1277.51251215572),
#  ({5, 81}, 1222.7097482772197),
#  ({5, 82}, 3762.863072681131),
#  ({5, 83}, 1316.6853428483712),
#  ({5, 84}, 281.55437686285126),
#  ({5, 85}, 1107.365890019225),
#  ({5, 86}, 3412.0533728506944),
#  ({5, 87}, 1033.402909619617),
#  ({5, 88}, 266.4771485771721),
#  ({5, 89}, 319.93991010744605),
#  ({5, 90}, 3142.0822099943457),
#  ({5, 91}, 1450.8654744312673),
#  ({5, 92}, 3160.1599337619373),
#  ({5, 93}, 2967.3469784675285),
#  ({5, 94}, 1169.3846633853125),
#  ({5, 95}, 1218.405178563432),
#  ({5, 96}, 1375.5388689443803),
#  ({5, 97}, 2538.059880714544),
#  ({5, 98}, 1214.1029869784734),
#  ({5, 99}, 1278.1844591365366),
#  ({5, 100}, 1277.9950877215795),
#  ({5, 101}, 1471.0258109619729),
#  ({5, 102}, 960.4851321948496),
#  ({5, 103}, 955.6366198110139),
#  ({5, 104}, 1779.8660973423007),
#  ({5, 105}, 1861.3679495089566),
#  ({5, 106}, 7628.057807582496),
#  ({5, 107}, 1924.1959990735547),
#  ({5, 108}, 1187.561570813923),
#  ({5, 109}, 3385.7466564754022),
#  ({5, 110}, 1676.7677323045045),
#  ({5, 111}, 186.26853472685883),
#  ({5, 112}, 272.8025950834587),
#  ({5, 113}, 3022.5467801845184),
#  ({5, 114}, 1075.6359421632656),
#  ({5, 115}, 1461.4696088547344),
#  ({5, 116}, 1811.8864800226856),
#  ({5, 117}, 1420.8162528951411),
#  ({5, 118}, 1124.4229249809844),
#  ({5, 119}, 1062.9877156889986),
#  ({5, 120}, 816.9440510300834),
#  ({5, 121}, 1277.658358393282),
#  ({5, 122}, 1135.7093660665903),
#  ({5, 123}, 2181.036510637561),
#  ({5, 124}, 3272.5007983892365),
#  ({5, 125}, 310.3514374382773),
#  ({5, 126}, 1233.0860496661005),
#  ({5, 127}, 1267.1164055146917),
#  ({5, 128}, 190.1564929882504),
#  ({5, 129}, 742.6735681466765),
#  ({5, 130}, 67.23201982270494),
#  ({5, 131}, 1439.2161507730532),
#  ({5, 132}, 2770.002919015693),
#  ({5, 133}, 1960.375217656487),
#  ({5, 134}, 1055.084793569742),
#  ({5, 135}, 301.03068774727114),
#  ({5, 136}, 861.0389599512841),
#  ({5, 137}, 2359.7355295692687),
#  ({5, 138}, 1122.9587688480444),
#  ({5, 139}, 3280.189137762378),
#  ({5, 140}, 1054.9637280573522),
#  ({5, 141}, 1369.731432812097),
#  ({5, 142}, 2160.7696018839574),
#  ({5, 143}, 1522.1623009269579),
#  ({5, 144}, 4807.087904355924),
#  ({5, 145}, 1162.7665118353473),
#  ({5, 146}, 6826.317336777505),
#  ({5, 147}, 1464.1426477862435),
#  ({5, 148}, 1647.5897446533),
#  ({5, 149}, 358.31781760112705),
#  ({5, 150}, 1241.348549962668),
#  ({5, 151}, 6863.264088336387),
#  ({5, 152}, 291.1492003090107),
#  ({5, 153}, 486.392348754242),
#  ({5, 154}, 1585.4805070027587),
#  ({5, 155}, 505.66516759789823),
#  ({5, 156}, 760.876764081421),
#  ({5, 157}, 5662.043654577754),
#  ({5, 158}, 1407.766294678776),
#  ({5, 159}, 1889.1637987414626),
#  ({5, 160}, 867.5727659704992),
#  ({5, 161}, 1378.9221910975448),
#  ({5, 162}, 7270.784706543906),
#  ({5, 163}, 1247.540201060997),
#  ({5, 164}, 1216.767020191898),
#  ({5, 165}, 1192.0469868336954),
#  ({5, 166}, 1734.2807166693876),
#  ({6, 7}, 6107.926557232488),
#  ({6, 8}, 6329.129567274878),
#  ({6, 9}, 6044.408180907699),
#  ({6, 10}, 6409.10247697263),
#  ({6, 11}, 3677.6670276300115),
#  ({6, 12}, 6819.9916145114585),
#  ({6, 13}, 6795.839218726326),
#  ({6, 14}, 5221.40524192329),
#  ({6, 15}, 3586.3937577228394),
#  ({6, 16}, 845.7575543541826),
#  ({6, 17}, 2589.314075095199),
#  ({6, 18}, 6753.642351024692),
#  ({6, 19}, 5877.738452480461),
#  ({6, 20}, 5078.1303043473),
#  ({6, 21}, 6227.415989479627),
#  ({6, 22}, 6848.394798014441),
#  ({6, 23}, 1697.1149625965845),
#  ({6, 24}, 6560.236667626147),
#  ({6, 25}, 5830.794656840633),
#  ...]

# %%
cyclic(edges)
# Out:
# False

# %%
import random

def simulated_annealing_tsp(dist_matrix, initial_tsp, initial_temp, cooling_rate, num_iterations):
    def scramble_mutation(tsp):
        a, b = sorted(random.sample(range(1, len(tsp) - 1), 2))
        tsp[a:b] = random.sample(tsp[a:b], len(tsp[a:b]))
        return tsp

    def tsp_cost(tsp):
        return sum(dist_matrix[tsp[i], tsp[i + 1]] for i in range(len(tsp) - 1))

    current_tsp = initial_tsp[:]
    current_cost = tsp_cost(current_tsp)
    best_tsp = current_tsp[:]
    best_cost = current_cost
    temp = initial_temp

    for i in range(num_iterations):
        new_tsp = scramble_mutation(current_tsp[:])
        new_cost = tsp_cost(new_tsp)
        if new_cost < current_cost or random.random() < np.exp((current_cost - new_cost) / temp):
            current_tsp = new_tsp
            current_cost = new_cost
            if new_cost < best_cost:
                best_tsp = new_tsp
                best_cost = new_cost
        temp *= cooling_rate

    return best_tsp, best_cost

# Parametri per Simulated Annealing
initial_temp = 1000
cooling_rate = 0.995
num_iterations = 10000

# TSP iniziale (usiamo il percorso trovato dal nearest neighbor come punto di partenza)
initial_tsp = tsp_path

# Esegui Simulated Annealing
optimized_tsp, optimized_cost = simulated_annealing_tsp(DIST_MATRIX, initial_tsp, initial_temp, cooling_rate, num_iterations)

logging.info(f"result: Found an optimized path of {len(optimized_tsp)-1} steps, total length {optimized_cost:.2f}km")
print(f"Optimized TSP Path: {optimized_tsp}")
print(f"Optimized Total Cost: {optimized_cost:.2f} km")
# Out:
# INFO:root:result: Found an optimized path of 46 steps, total length 44628.65km
# Optimized TSP Path: [0, np.int64(33), np.int64(25), np.int64(19), np.int64(44), np.int64(4), np.int64(32), np.int64(43), np.int64(18), np.int64(12), np.int64(28), np.int64(5), np.int64(22), np.int64(45), np.int64(30), np.int64(42), np.int64(9), np.int64(20), np.int64(40), np.int64(3), np.int64(23), np.int64(6), np.int64(41), np.int64(14), np.int64(39), np.int64(10), np.int64(35), np.int64(34), np.int64(13), np.int64(38), np.int64(37), np.int64(7), np.int64(26), np.int64(21), np.int64(2), np.int64(17), np.int64(16), np.int64(31), np.int64(1), np.int64(15), np.int64(11), np.int64(36), np.int64(24), np.int64(8), np.int64(29), np.int64(27), 0]
# Optimized Total Cost: 44628.65 km

# %% [markdown]
# ## Genetic Algorithm
# - steady state: offsprings compete with the parents
# - parent selection: we try different methods
# - mutation: we try different methods (scramble, inversion)
# - crossover: we try different methods (edge recombination, inver over)
#
# Fitness is defined as the inverse of the sum of the distance between adjacent cities and the distance between the first and the last city.

# %%
def fitness(path):
    distance = 0
    for i in range(len(path) - 1):
        distance += DIST_MATRIX[path[i], path[i + 1]]
    distance += DIST_MATRIX[path[-1], path[0]]
    return 1/distance  # greater is the distance lower (worse) is the fitness

# %% [markdown]
# ### Parent Selection

# %%
def parent_selection(population, fitnesses, method, num_parents = 20):
    parents = []
    if method == 0 : # Roulette Wheel
        total_fitness = sum(fitnesses)
        relative_fitness = [f/total_fitness for f in fitnesses]  # 
        # Select num_parents from the population using relative fitness
        mating_pool = np.random.choice(range(len(population)), num_parents, p=relative_fitness)
        parents = [population[i] for i in mating_pool]
        
    elif method == 1: # Tournament Selection
        for _ in range(num_parents):
            # Select random indices for the tournament
            tournament_indices = np.random.choice(range(len(population)), int(0.3 * len(population)), replace=False)
            tournament_fitnesses = [fitnesses[i] for i in tournament_indices]
            
            # Select the individual with the best fitness in the tournament
            best_index = tournament_indices[np.argmax(tournament_fitnesses)]
            parents.append(population[best_index])
    
    elif method == 2: # Rank Selection
        rank = np.argsort(fitnesses)
        for i in range(num_parents):
            parents.append(population[rank[i]])
            
    else:
        logging.error("Invalid parent selection method")

    return parents

# %% [markdown]
# ### Crossover

# %%
# edge recombination operator crossover

def edge_recombination(parent1, parent2):
    # Step 1: Create an adjacency list
    adjacency_list = {}
    for city in parent1:
        adjacency_list[city] = set()

    # Populate adjacency lists with neighbors from parent1
    for i in range(len(parent1)):
        left_neighbor = parent1[i - 1] if i > 0 else parent1[-1]
        right_neighbor = parent1[i + 1] if i < len(parent1) - 1 else parent1[0]
        adjacency_list[parent1[i]].update([left_neighbor, right_neighbor])

    # Populate adjacency lists with neighbors from parent2
    for i in range(len(parent2)):
        left_neighbor = parent2[i - 1] if i > 0 else parent2[-1]
        right_neighbor = parent2[i + 1] if i < len(parent2) - 1 else parent2[0]
        adjacency_list[parent2[i]].update([left_neighbor, right_neighbor])

    # Step 2: Initialize the offspring with the first city from parent1
    current_city = parent1[0]
    offspring = [current_city]

    # Step 3: Generate the rest of the offspring sequence
    while len(offspring) < len(parent1):
        # Remove the current city from all neighbors in the adjacency list
        for neighbors in adjacency_list.values():
            neighbors.discard(current_city)

        # Find the next city with the fewest neighbors
        if adjacency_list[current_city]:
            next_city = min(adjacency_list[current_city], key=lambda x: len(adjacency_list[x]))
        else:
            # If no adjacent city is available, pick a random city not in offspring
            next_city = random.choice([city for city in parent1 if city not in offspring])

        offspring.append(next_city)
        current_city = next_city

    return offspring

def inver_over(parent1, parent2, p=0.5):
    # Initialize offspring as a copy of parent1
    offspring = parent1[:]
    n = len(offspring)
    
    # Set of cities already processed
    visited = set()

    # Start from a random city in parent1
    current_city = random.choice(offspring)
    visited.add(current_city)

    while len(visited) < n:
        # With probability p, pick the current city from the other parent
        if random.random() < p:
            # Choose the next city based on parent2's adjacency
            next_city_index = parent2.index(current_city)
            if next_city_index == n - 1:
                next_city = parent2[0]  # Wrap around
            else:
                next_city = parent2[next_city_index + 1]
        else:
            # Choose a random unvisited city
            next_city = random.choice([city for city in offspring if city not in visited])

        # Find positions of current and next city in offspring
        current_index = offspring.index(current_city)
        next_index = offspring.index(next_city)

        # Invert the segment between current and next city
        if current_index < next_index:
            offspring[current_index:next_index + 1] = reversed(offspring[current_index:next_index + 1])
        else:
            # Wrap around if next_index is "before" current_index
            segment = offspring[current_index:] + offspring[:next_index + 1]
            segment.reverse()
            offspring[current_index:] = segment[:n - current_index]
            offspring[:next_index + 1] = segment[n - current_index:]

        # Mark the next city as visited and move to it
        visited.add(next_city)
        current_city = next_city

    return offspring

# %% [markdown]
# ### Mutation

# %%
def scramble_mutation(path):
    # Choose two random points in the sequence to define the subset
    start, end = sorted(random.sample(range(len(path)), 2))

    # Scramble the subset
    subset = path[start:end + 1]
    random.shuffle(subset)

    # Place the scrambled subset back in the path
    mutated_path = path[:start] + subset + path[end + 1:]
    return mutated_path


def inversion_mutation(path):
    # Choose two random points in the path
    start, end = sorted(random.sample(range(len(path)), 2))

    # Reverse the subset
    mutated_path = path[:start] + path[start:end + 1][::-1] + path[end + 1:]
    return mutated_path


def adaptive_mutation(path, generation, max_generations, mutation_fn):
    """Mutation rate adapts based on generation progress"""
    # Higher mutation rate early, lower later
    mutation_rate = 0.3 * (1 - generation / max_generations)
    
    if random.random() < mutation_rate:
        return mutation_fn(path)
    return path

# %% [markdown]
# ### Genetic Algorithm

# %%
def print_path_details(path, cities_df, dist_matrix):
    """
    Print detailed information about a TSP path including city-to-city steps and distances
    
    Parameters:
    path: list of indices representing the city order
    cities_df: DataFrame containing city information with 'name' column
    dist_matrix: distance matrix between cities
    """
    total_distance = 0
    steps = 0
    
    # Convert numpy integers to regular Python integers
    path = [int(i) for i in path]
    
    # Print each step in the path
    for i in range(len(path)):
        current_city = cities_df.iloc[path[i]]['name']
        next_city = cities_df.iloc[path[(i + 1) % len(path)]]['name']
        distance = dist_matrix[path[i], path[(i + 1) % len(path)]]
        
        logging.debug(f"step: {current_city} -> {next_city} ({distance:.2f}km)")
        total_distance += distance
        steps += 1
    
    logging.info(f"result: Found a path of {steps} steps, total length {total_distance:.2f}km")
    return total_distance, steps

# %%
import numpy as np

def genetic_algorithm(population_size, num_generations, crossover_fn, mutation_fn, parent_selection_fn, p_selection_method):
    # Set replacement rate - 30% of population
    replacement_rate = 0.5
    num_replacements = int(population_size * replacement_rate)
    
    # Initialize the population with random TSP paths
    population = [list(np.random.permutation(len(CITIES))) for _ in range(population_size)]
    best_path = None
    best_fitness = float('-inf')

    # Evaluate the initial population
    fitness_values = [fitness(path) for path in population]

    for generation in range(num_generations):
        # Select a few parents for crossover
        parents = parent_selection_fn(population, fitness_values, p_selection_method)

        # Generate offspring by crossover and mutation
        next_generation = []
        for i in range(0, len(parents), 2):
            child1 = crossover_fn(parents[i], parents[i + 1])
            child2 = crossover_fn(parents[i + 1], parents[i])
            next_generation.extend([adaptive_mutation(child1,generation,num_generations,mutation_fn), adaptive_mutation(child2,generation,num_generations,mutation_fn)])

        # Calculate fitness for the offspring
        offspring_fitness = [fitness(child) for child in next_generation]

        # Replace the least fit individuals with new offspring
        for child, child_fitness in zip(next_generation[:num_replacements], offspring_fitness[:num_replacements]):
            # Find the index of the least fit individual in the population
            least_fit_index = np.argmin(fitness_values)
            if child_fitness > fitness_values[least_fit_index]:
                # Replace least fit individual with the new child
                population[least_fit_index] = child
                fitness_values[least_fit_index] = child_fitness

                # Update best path and fitness if needed
                if child_fitness > best_fitness:
                    best_path = child
                    best_fitness = child_fitness

        if generation % 10 == 0:
            logging.info(f"Generation {generation}: Best Fitness = {1/best_fitness:.4f}")

    
            
    # Print final path details
    logging.info("Final path details:")
    total_distance, steps = print_path_details(best_path, CITIES, DIST_MATRIX)
    
    # Print the actual path of city names for easier comparison
    city_path = [CITIES.iloc[i]['name'] for i in best_path]
    logging.info(f"Optimized TSP Path: {city_path}")
    logging.info(f"Optimized Total Cost: {1/best_fitness:.2f} km")
    
    
    return best_path, best_fitness

# %% [markdown]
# ## Iterations

# %%
# Params for Genetic Algorithm
population_size = 200
num_generations = 10000
crossover_fn = edge_recombination
mutation_fn = inversion_mutation
parent_selection_fn = parent_selection
p_selection_method = 0  # 0: Roulette Wheel, 1: Tournament Selection, 2: Rank Selection

# Run Genetic Algorithm
best_path, best_fitness = genetic_algorithm(population_size, num_generations, crossover_fn, mutation_fn, parent_selection_fn, p_selection_method)
# Out:
# INFO:root:Generation 0: Best Fitness = 322984.3257
# INFO:root:Generation 10: Best Fitness = 304677.6960
# INFO:root:Generation 20: Best Fitness = 283430.5407
# INFO:root:Generation 30: Best Fitness = 268035.8847
# INFO:root:Generation 40: Best Fitness = 258764.9824
# INFO:root:Generation 50: Best Fitness = 255146.7665
# INFO:root:Generation 60: Best Fitness = 243123.8839
# INFO:root:Generation 70: Best Fitness = 241981.3710
# INFO:root:Generation 80: Best Fitness = 234134.9339
# INFO:root:Generation 90: Best Fitness = 213887.3223
# INFO:root:Generation 100: Best Fitness = 213887.3223
# INFO:root:Generation 110: Best Fitness = 206749.3541
# INFO:root:Generation 120: Best Fitness = 197776.2914
# INFO:root:Generation 130: Best Fitness = 197776.2914
# INFO:root:Generation 140: Best Fitness = 194744.9715
# INFO:root:Generation 150: Best Fitness = 194744.9715
# INFO:root:Generation 160: Best Fitness = 192474.1300
# INFO:root:Generation 170: Best Fitness = 179888.8513
# INFO:root:Generation 180: Best Fitness = 176380.4450
# INFO:root:Generation 190: Best Fitness = 173766.7455
# INFO:root:Generation 200: Best Fitness = 173766.7455
# INFO:root:Generation 210: Best Fitness = 173766.7455
# INFO:root:Generation 220: Best Fitness = 171039.2699
# INFO:root:Generation 230: Best Fitness = 171039.2699
# INFO:root:Generation 240: Best Fitness = 171039.2699
# INFO:root:Generation 250: Best Fitness = 166600.2916
# INFO:root:Generation 260: Best Fitness = 165156.2224
# INFO:root:Generation 270: Best Fitness = 164911.2020
# INFO:root:Generation 280: Best Fitness = 163416.7355
# INFO:root:Generation 290: Best Fitness = 161651.0492
# INFO:root:Generation 300: Best Fitness = 156731.9744
# INFO:root:Generation 310: Best Fitness = 151268.4198
# INFO:root:Generation 320: Best Fitness = 151268.4198
# INFO:root:Generation 330: Best Fitness = 150153.2124
# INFO:root:Generation 340: Best Fitness = 149078.5871
# INFO:root:Generation 350: Best Fitness = 149078.5871
# INFO:root:Generation 360: Best Fitness = 139668.7412
# INFO:root:Generation 370: Best Fitness = 139668.7412
# INFO:root:Generation 380: Best Fitness = 139668.7412
# INFO:root:Generation 390: Best Fitness = 139668.7412
# INFO:root:Generation 400: Best Fitness = 139668.7412
# INFO:root:Generation 410: Best Fitness = 139668.7412
# INFO:root:Generation 420: Best Fitness = 139639.4760
# INFO:root:Generation 430: Best Fitness = 139639.4760
# INFO:root:Generation 440: Best Fitness = 139639.4760
# INFO:root:Generation 450: Best Fitness = 138151.8431
# INFO:root:Generation 460: Best Fitness = 134596.3885
# INFO:root:Generation 470: Best Fitness = 134596.3885
# INFO:root:Generation 480: Best Fitness = 134596.3885
# INFO:root:Generation 490: Best Fitness = 134596.3885
# INFO:root:Generation 500: Best Fitness = 132395.4898
# INFO:root:Generation 510: Best Fitness = 129523.9702
# INFO:root:Generation 520: Best Fitness = 129523.9702
# INFO:root:Generation 530: Best Fitness = 129523.9702
# INFO:root:Generation 540: Best Fitness = 127747.9137
# INFO:root:Generation 550: Best Fitness = 127747.9137
# INFO:root:Generation 560: Best Fitness = 127747.9137
# INFO:root:Generation 570: Best Fitness = 123957.4583
# INFO:root:Generation 580: Best Fitness = 123957.4583
# INFO:root:Generation 590: Best Fitness = 123957.4583
# INFO:root:Generation 600: Best Fitness = 123957.4583
# INFO:root:Generation 610: Best Fitness = 123452.8628
# INFO:root:Generation 620: Best Fitness = 123452.8628
# INFO:root:Generation 630: Best Fitness = 123410.9588
# INFO:root:Generation 640: Best Fitness = 123410.9588
# INFO:root:Generation 650: Best Fitness = 122459.6410
# INFO:root:Generation 660: Best Fitness = 122134.6733
# INFO:root:Generation 670: Best Fitness = 120467.0981
# INFO:root:Generation 680: Best Fitness = 120467.0981
# INFO:root:Generation 690: Best Fitness = 119706.0017
# INFO:root:Generation 700: Best Fitness = 117099.7023
# INFO:root:Generation 710: Best Fitness = 117099.7023
# INFO:root:Generation 720: Best Fitness = 115254.5587
# INFO:root:Generation 730: Best Fitness = 115254.5587
# INFO:root:Generation 740: Best Fitness = 115254.5587
# INFO:root:Generation 750: Best Fitness = 115254.5587
# INFO:root:Generation 760: Best Fitness = 114692.4453
# INFO:root:Generation 770: Best Fitness = 114692.4453
# INFO:root:Generation 780: Best Fitness = 111955.1073
# INFO:root:Generation 790: Best Fitness = 111955.1073
# INFO:root:Generation 800: Best Fitness = 111955.1073
# INFO:root:Generation 810: Best Fitness = 111955.1073
# INFO:root:Generation 820: Best Fitness = 111955.1073
# INFO:root:Generation 830: Best Fitness = 110157.5155
# INFO:root:Generation 840: Best Fitness = 110157.5155
# INFO:root:Generation 850: Best Fitness = 110157.5155
# INFO:root:Generation 860: Best Fitness = 108712.1277
# INFO:root:Generation 870: Best Fitness = 108285.5250
# INFO:root:Generation 880: Best Fitness = 107864.0582
# INFO:root:Generation 890: Best Fitness = 107534.7289
# INFO:root:Generation 900: Best Fitness = 106558.0069
# INFO:root:Generation 910: Best Fitness = 104031.2015
# INFO:root:Generation 920: Best Fitness = 104031.2015
# INFO:root:Generation 930: Best Fitness = 104031.2015
# INFO:root:Generation 940: Best Fitness = 103142.8536
# INFO:root:Generation 950: Best Fitness = 101856.7735
# INFO:root:Generation 960: Best Fitness = 101856.7735
# INFO:root:Generation 970: Best Fitness = 100201.4688
# INFO:root:Generation 980: Best Fitness = 100201.4688
# INFO:root:Generation 990: Best Fitness = 100201.4688
# INFO:root:Final path details:
# DEBUG:root:step: Taganrog -> Saratov (707.35km)
# DEBUG:root:step: Saratov -> Yelets (527.80km)
# DEBUG:root:step: Yelets -> Izhevsk (1056.95km)
# DEBUG:root:step: Izhevsk -> Kopeysk (559.74km)
# DEBUG:root:step: Kopeysk -> Oktyabrskiy (531.33km)
# DEBUG:root:step: Oktyabrskiy -> Ivanovo (831.30km)
# DEBUG:root:step: Ivanovo -> Dimitrovgrad (619.96km)
# DEBUG:root:step: Dimitrovgrad -> Pervouralsk (718.71km)
# DEBUG:root:step: Pervouralsk -> Tobolsk (518.00km)
# DEBUG:root:step: Tobolsk -> Omsk (475.40km)
# DEBUG:root:step: Omsk -> Kemerovo (807.83km)
# DEBUG:root:step: Kemerovo -> Abakan (389.87km)
# DEBUG:root:step: Abakan -> Bratsk (716.77km)
# DEBUG:root:step: Bratsk -> Achinsk (693.41km)
# DEBUG:root:step: Achinsk -> Miass (1904.59km)
# DEBUG:root:step: Miass -> Novorossiysk (1956.49km)
# DEBUG:root:step: Novorossiysk -> Volgograd (677.73km)
# DEBUG:root:step: Volgograd -> Nazran (611.83km)
# DEBUG:root:step: Nazran -> Rostov‐na‐Donu (600.07km)
# DEBUG:root:step: Rostov‐na‐Donu -> Tambov (622.93km)
# DEBUG:root:step: Tambov -> Ulyanovsk (495.05km)
# DEBUG:root:step: Ulyanovsk -> Sergiyev Posad (687.73km)
# DEBUG:root:step: Sergiyev Posad -> Novoshakhtinsk (961.53km)
# DEBUG:root:step: Novoshakhtinsk -> Sochi (461.54km)
# DEBUG:root:step: Sochi -> Maykop (116.28km)
# DEBUG:root:step: Maykop -> Astrakhan (649.88km)
# DEBUG:root:step: Astrakhan -> Nalchik (471.70km)
# DEBUG:root:step: Nalchik -> Volgodonsk (460.22km)
# DEBUG:root:step: Volgodonsk -> Kursk (636.58km)
# DEBUG:root:step: Kursk -> Staryy Oskol (124.13km)
# DEBUG:root:step: Staryy Oskol -> Nizhny Novgorod (690.83km)
# DEBUG:root:step: Nizhny Novgorod -> Perm (762.96km)
# DEBUG:root:step: Perm -> Leninsk‐Kuznetskiy (1870.90km)
# DEBUG:root:step: Leninsk‐Kuznetskiy -> Kyzyl (639.52km)
# DEBUG:root:step: Kyzyl -> Novosibirsk (846.03km)
# DEBUG:root:step: Novosibirsk -> Rubtsovsk (407.28km)
# DEBUG:root:step: Rubtsovsk -> Barnaul (267.42km)
# DEBUG:root:step: Barnaul -> Krasnoyarsk (668.69km)
# DEBUG:root:step: Krasnoyarsk -> Prokopyevsk (470.01km)
# DEBUG:root:step: Prokopyevsk -> Novokuznetsk (30.63km)
# DEBUG:root:step: Novokuznetsk -> Biysk (187.38km)
# DEBUG:root:step: Biysk -> Nefteyugansk (1215.14km)
# DEBUG:root:step: Nefteyugansk -> Norilsk (1165.94km)
# DEBUG:root:step: Norilsk -> Angarsk (2038.46km)
# DEBUG:root:step: Angarsk -> Irkutsk (34.88km)
# DEBUG:root:step: Irkutsk -> Chita (630.87km)
# DEBUG:root:step: Chita -> Vladivostok (1697.13km)
# DEBUG:root:step: Vladivostok -> Nakhodka (87.36km)
# DEBUG:root:step: Nakhodka -> Ussuriysk (129.26km)
# DEBUG:root:step: Ussuriysk -> Artyom (50.78km)
# DEBUG:root:step: Artyom -> Magadan (2203.06km)
# DEBUG:root:step: Magadan -> Blagoveshchensk (1800.86km)
# DEBUG:root:step: Blagoveshchensk -> Komsomolsk‐na‐Amure (673.41km)
# DEBUG:root:step: Komsomolsk‐na‐Amure -> Yuzhno‐Sakhalinsk (582.17km)
# DEBUG:root:step: Yuzhno‐Sakhalinsk -> Petropavlovsk‐Kamchatskiy (1321.54km)
# DEBUG:root:step: Petropavlovsk‐Kamchatskiy -> Khabarovsk (1729.61km)
# DEBUG:root:step: Khabarovsk -> Ulan‐Ude (1990.25km)
# DEBUG:root:step: Ulan‐Ude -> Yakutsk (1745.85km)
# DEBUG:root:step: Yakutsk -> Tomsk (2569.92km)
# DEBUG:root:step: Tomsk -> Seversk (14.97km)
# DEBUG:root:step: Seversk -> Noyabrsk (892.58km)
# DEBUG:root:step: Noyabrsk -> Nizhnevartovsk (254.53km)
# DEBUG:root:step: Nizhnevartovsk -> Novyy Urengoy (575.19km)
# DEBUG:root:step: Novyy Urengoy -> Tyumen (1150.32km)
# DEBUG:root:step: Tyumen -> Surgut (640.95km)
# DEBUG:root:step: Surgut -> Chelyabinsk (976.35km)
# DEBUG:root:step: Chelyabinsk -> Novotroitsk (485.16km)
# DEBUG:root:step: Novotroitsk -> Neftekamsk (604.34km)
# DEBUG:root:step: Neftekamsk -> Almetyevsk (180.57km)
# DEBUG:root:step: Almetyevsk -> Yoshkar‐Ola (339.28km)
# DEBUG:root:step: Yoshkar‐Ola -> Kostroma (437.68km)
# DEBUG:root:step: Kostroma -> Moscow (302.56km)
# DEBUG:root:step: Moscow -> Saint Petersburg (635.48km)
# DEBUG:root:step: Saint Petersburg -> Velikiy Novgorod (166.36km)
# DEBUG:root:step: Velikiy Novgorod -> Zelenograd (462.65km)
# DEBUG:root:step: Zelenograd -> Podolsk (59.99km)
# DEBUG:root:step: Podolsk -> Balashikha (49.57km)
# DEBUG:root:step: Balashikha -> Elektrostal (30.75km)
# DEBUG:root:step: Elektrostal -> Khimki (63.63km)
# DEBUG:root:step: Khimki -> Orekhovo‐Zuevo (96.76km)
# DEBUG:root:step: Orekhovo‐Zuevo -> Petrozavodsk (719.88km)
# DEBUG:root:step: Petrozavodsk -> Bryansk (953.33km)
# DEBUG:root:step: Bryansk -> Dzerzhinsk (669.24km)
# DEBUG:root:step: Dzerzhinsk -> Korolyov (352.87km)
# DEBUG:root:step: Korolyov -> Novocheboksarsk (603.56km)
# DEBUG:root:step: Novocheboksarsk -> Vologda (569.43km)
# DEBUG:root:step: Vologda -> Rybinsk (144.38km)
# DEBUG:root:step: Rybinsk -> Cheboksary (552.96km)
# DEBUG:root:step: Cheboksary -> Ryazan (504.60km)
# DEBUG:root:step: Ryazan -> Serpukhov (153.62km)
# DEBUG:root:step: Serpukhov -> Noginsk (122.40km)
# DEBUG:root:step: Noginsk -> Balakovo (745.33km)
# DEBUG:root:step: Balakovo -> Khasavyurt (980.24km)
# DEBUG:root:step: Khasavyurt -> Stavropol (419.67km)
# DEBUG:root:step: Stavropol -> Orenberg (1224.54km)
# DEBUG:root:step: Orenberg -> Sterlitamak (213.37km)
# DEBUG:root:step: Sterlitamak -> Berezniki (645.57km)
# DEBUG:root:step: Berezniki -> Nizhniy Tagil (249.01km)
# DEBUG:root:step: Nizhniy Tagil -> Orsk (751.90km)
# DEBUG:root:step: Orsk -> Kurgan (649.00km)
# DEBUG:root:step: Kurgan -> Kamensk‐Uralskiy (237.85km)
# DEBUG:root:step: Kamensk‐Uralskiy -> Yekaterinburg (95.20km)
# DEBUG:root:step: Yekaterinburg -> Zlatoust (196.21km)
# DEBUG:root:step: Zlatoust -> Salavat (314.88km)
# DEBUG:root:step: Salavat -> Tolyatti (426.14km)
# DEBUG:root:step: Tolyatti -> Engels (318.63km)
# DEBUG:root:step: Engels -> Kamyshin (163.80km)
# DEBUG:root:step: Kamyshin -> Derbent (921.01km)
# DEBUG:root:step: Derbent -> Vladikavkaz (315.82km)
# DEBUG:root:step: Vladikavkaz -> Elista (366.39km)
# DEBUG:root:step: Elista -> Shakhty (341.08km)
# DEBUG:root:step: Shakhty -> Novocherkassk (33.48km)
# DEBUG:root:step: Novocherkassk -> Kaliningrad (1586.87km)
# DEBUG:root:step: Kaliningrad -> Pskov (596.10km)
# DEBUG:root:step: Pskov -> Tver (467.55km)
# DEBUG:root:step: Tver -> Velikie Luki (334.19km)
# DEBUG:root:step: Velikie Luki -> Zheleznodorozhnyy (470.93km)
# DEBUG:root:step: Zheleznodorozhnyy -> Tula (174.50km)
# DEBUG:root:step: Tula -> Mytishchi (190.52km)
# DEBUG:root:step: Mytishchi -> Syktyvkar (988.68km)
# DEBUG:root:step: Syktyvkar -> Arkhangelsk (610.18km)
# DEBUG:root:step: Arkhangelsk -> Severodvinsk (33.55km)
# DEBUG:root:step: Severodvinsk -> Cherkessk (2261.65km)
# DEBUG:root:step: Cherkessk -> Armavir (107.76km)
# DEBUG:root:step: Armavir -> Kislovodsk (174.98km)
# DEBUG:root:step: Kislovodsk -> Belgorod (876.86km)
# DEBUG:root:step: Belgorod -> Lipetsk (306.64km)
# DEBUG:root:step: Lipetsk -> Kovrov (430.61km)
# DEBUG:root:step: Kovrov -> Murom (98.78km)
# DEBUG:root:step: Murom -> Voronezh (466.18km)
# DEBUG:root:step: Voronezh -> Novomoskovsk (272.86km)
# DEBUG:root:step: Novomoskovsk -> Smolensk (408.17km)
# DEBUG:root:step: Smolensk -> Obninsk (294.99km)
# DEBUG:root:step: Obninsk -> Kolpino (630.76km)
# DEBUG:root:step: Kolpino -> Zhukovskiy (653.01km)
# DEBUG:root:step: Zhukovskiy -> Odintsovo (61.96km)
# DEBUG:root:step: Odintsovo -> Arzamas (413.52km)
# DEBUG:root:step: Arzamas -> Kolomna (322.35km)
# DEBUG:root:step: Kolomna -> Vladimir (156.04km)
# DEBUG:root:step: Vladimir -> Shchyolkovo (150.80km)
# DEBUG:root:step: Shchyolkovo -> Lyubertsy (26.88km)
# DEBUG:root:step: Lyubertsy -> Yaroslavl (248.78km)
# DEBUG:root:step: Yaroslavl -> Cherepovets (203.88km)
# DEBUG:root:step: Cherepovets -> Murmansk (1119.98km)
# DEBUG:root:step: Murmansk -> Naberezhnye Chelny (1766.84km)
# DEBUG:root:step: Naberezhnye Chelny -> Kirov (361.80km)
# DEBUG:root:step: Kirov -> Kazan (319.00km)
# DEBUG:root:step: Kazan -> Ufa (452.15km)
# DEBUG:root:step: Ufa -> Magnitogorsk (244.21km)
# DEBUG:root:step: Magnitogorsk -> Orenburg (319.40km)
# DEBUG:root:step: Orenburg -> Samara (371.40km)
# DEBUG:root:step: Samara -> Penza (344.08km)
# DEBUG:root:step: Penza -> Syzran (231.97km)
# DEBUG:root:step: Syzran -> Makhachkala (1135.32km)
# DEBUG:root:step: Makhachkala -> Groznyy (150.94km)
# DEBUG:root:step: Groznyy -> Nevinnomyssk (334.72km)
# DEBUG:root:step: Nevinnomyssk -> Bataysk (327.07km)
# DEBUG:root:step: Bataysk -> Volzhskiy (417.24km)
# DEBUG:root:step: Volzhskiy -> Krasnodar (607.37km)
# DEBUG:root:step: Krasnodar -> Kaspiysk (734.57km)
# DEBUG:root:step: Kaspiysk -> Pyatigorsk (392.70km)
# DEBUG:root:step: Pyatigorsk -> Oryol (1116.72km)
# DEBUG:root:step: Oryol -> Kaluga (175.19km)
# DEBUG:root:step: Kaluga -> Nizhnekamsk (998.26km)
# DEBUG:root:step: Nizhnekamsk -> Novokuybyshevsk (307.21km)
# DEBUG:root:step: Novokuybyshevsk -> Saransk (335.86km)
# DEBUG:root:step: Saransk -> Taganrog (891.20km)
# INFO:root:result: Found a path of 167 steps, total length 99951.60km
# INFO:root:Optimized TSP Path: ['Taganrog', 'Saratov', 'Yelets', 'Izhevsk', 'Kopeysk', 'Oktyabrskiy', 'Ivanovo', 'Dimitrovgrad', 'Pervouralsk', 'Tobolsk', 'Omsk', 'Kemerovo', 'Abakan', 'Bratsk', 'Achinsk', 'Miass', 'Novorossiysk', 'Volgograd', 'Nazran', 'Rostov‐na‐Donu', 'Tambov', 'Ulyanovsk', 'Sergiyev Posad', 'Novoshakhtinsk', 'Sochi', 'Maykop', 'Astrakhan', 'Nalchik', 'Volgodonsk', 'Kursk', 'Staryy Oskol', 'Nizhny Novgorod', 'Perm', 'Leninsk‐Kuznetskiy', 'Kyzyl', 'Novosibirsk', 'Rubtsovsk', 'Barnaul', 'Krasnoyarsk', 'Prokopyevsk', 'Novokuznetsk', 'Biysk', 'Nefteyugansk', 'Norilsk', 'Angarsk', 'Irkutsk', 'Chita', 'Vladivostok', 'Nakhodka', 'Ussuriysk', 'Artyom', 'Magadan', 'Blagoveshchensk', 'Komsomolsk‐na‐Amure', 'Yuzhno‐Sakhalinsk', 'Petropavlovsk‐Kamchatskiy', 'Khabarovsk', 'Ulan‐Ude', 'Yakutsk', 'Tomsk', 'Seversk', 'Noyabrsk', 'Nizhnevartovsk', 'Novyy Urengoy', 'Tyumen', 'Surgut', 'Chelyabinsk', 'Novotroitsk', 'Neftekamsk', 'Almetyevsk', 'Yoshkar‐Ola', 'Kostroma', 'Moscow', 'Saint Petersburg', 'Velikiy Novgorod', 'Zelenograd', 'Podolsk', 'Balashikha', 'Elektrostal', 'Khimki', 'Orekhovo‐Zuevo', 'Petrozavodsk', 'Bryansk', 'Dzerzhinsk', 'Korolyov', 'Novocheboksarsk', 'Vologda', 'Rybinsk', 'Cheboksary', 'Ryazan', 'Serpukhov', 'Noginsk', 'Balakovo', 'Khasavyurt', 'Stavropol', 'Orenberg', 'Sterlitamak', 'Berezniki', 'Nizhniy Tagil', 'Orsk', 'Kurgan', 'Kamensk‐Uralskiy', 'Yekaterinburg', 'Zlatoust', 'Salavat', 'Tolyatti', 'Engels', 'Kamyshin', 'Derbent', 'Vladikavkaz', 'Elista', 'Shakhty', 'Novocherkassk', 'Kaliningrad', 'Pskov', 'Tver', 'Velikie Luki', 'Zheleznodorozhnyy', 'Tula', 'Mytishchi', 'Syktyvkar', 'Arkhangelsk', 'Severodvinsk', 'Cherkessk', 'Armavir', 'Kislovodsk', 'Belgorod', 'Lipetsk', 'Kovrov', 'Murom', 'Voronezh', 'Novomoskovsk', 'Smolensk', 'Obninsk', 'Kolpino', 'Zhukovskiy', 'Odintsovo', 'Arzamas', 'Kolomna', 'Vladimir', 'Shchyolkovo', 'Lyubertsy', 'Yaroslavl', 'Cherepovets', 'Murmansk', 'Naberezhnye Chelny', 'Kirov', 'Kazan', 'Ufa', 'Magnitogorsk', 'Orenburg', 'Samara', 'Penza', 'Syzran', 'Makhachkala', 'Groznyy', 'Nevinnomyssk', 'Bataysk', 'Volzhskiy', 'Krasnodar', 'Kaspiysk', 'Pyatigorsk', 'Oryol', 'Kaluga', 'Nizhnekamsk', 'Novokuybyshevsk', 'Saransk']
# INFO:root:Optimized Total Cost: 99951.60 km
# INFO:root:result: Found an optimized path of 166 steps, total length 99951.60km
# Optimized TSP Path: [np.int32(135), np.int32(120), np.int32(160), np.int32(33), np.int32(49), np.int32(96), np.int32(32), np.int32(25), np.int32(105), np.int32(137), np.int32(97), np.int32(40), np.int32(0), np.int32(17), np.int32(1), np.int32(65), np.int32(88), np.int32(153), np.int32(73), np.int32(112), np.int32(136), np.int32(145), np.int32(121), np.int32(89), np.int32(128), np.int32(64), np.int32(8), np.int32(72), np.int32(152), np.int32(56), np.int32(129), np.int32(80), np.int32(104), np.int32(58), np.int32(57), np.int32(90), np.int32(113), np.int32(11), np.int32(54), np.int32(109), np.int32(86), np.int32(15), np.int32(75), np.int32(82), np.int32(3), np.int32(31), np.int32(23), np.int32(151), np.int32(71), np.int32(146), np.int32(6), np.int32(61), np.int32(16), np.int32(48), np.int32(162), np.int32(106), np.int32(41), np.int32(144), np.int32(157), np.int32(139), np.int32(124), np.int32(93), np.int32(78), np.int32(92), np.int32(142), np.int32(132), np.int32(20), np.int32(91), np.int32(74), np.int32(2), np.int32(161), np.int32(51), np.int32(66), np.int32(116), np.int32(148), np.int32(163), np.int32(108), np.int32(10), np.int32(27), np.int32(43), np.int32(98), np.int32(107), np.int32(18), np.int32(26), np.int32(50), np.int32(83), np.int32(154), np.int32(115), np.int32(19), np.int32(114), np.int32(122), np.int32(81), np.int32(9), np.int32(42), np.int32(130), np.int32(99), np.int32(131), np.int32(14), np.int32(79), np.int32(101), np.int32(55), np.int32(36), np.int32(159), np.int32(166), np.int32(117), np.int32(138), np.int32(29), np.int32(37), np.int32(24), np.int32(149), np.int32(28), np.int32(125), np.int32(84), np.int32(34), np.int32(110), np.int32(141), np.int32(147), np.int32(164), np.int32(140), np.int32(69), np.int32(133), np.int32(4), np.int32(123), np.int32(22), np.int32(5), np.int32(45), np.int32(13), np.int32(59), np.int32(52), np.int32(68), np.int32(156), np.int32(87), np.int32(127), np.int32(94), np.int32(47), np.int32(165), np.int32(95), np.int32(7), np.int32(46), np.int32(150), np.int32(126), np.int32(60), np.int32(158), np.int32(21), np.int32(67), np.int32(70), np.int32(44), np.int32(39), np.int32(143), np.int32(62), np.int32(100), np.int32(118), np.int32(103), np.int32(134), np.int32(63), np.int32(30), np.int32(76), np.int32(12), np.int32(155), np.int32(53), np.int32(38), np.int32(111), np.int32(102), np.int32(35), np.int32(77), np.int32(85), np.int32(119)]
# Optimized Total Cost: 99951.60 km
